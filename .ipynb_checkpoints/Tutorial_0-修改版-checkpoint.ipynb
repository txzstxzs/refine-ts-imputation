# %% [markdown]
# # Diffusion-TS Tutorial
#
# ## Diffusion-TS: Interpretable Diffusion for General Time Series Generation
#
# This notebook describes the user-guide of a time-series synthetic data generation application using Diffusion-TS framework.

# %% [markdown]
# ## Necessary packages and functions call

# %%
'-----sine数据集设置epoch 7000往上时pca和tsne效果较好 几乎完全重合 虽然设置7000以下等值也可以较早收敛 最终loss值也差不多 但是pca等效果没有那么好-----'

import os
import torch
import numpy as np

from engine.solver import Trainer
from Utils.metric_utils import visualization
from Data.build_dataloader import build_dataloader
from Utils.io_utils import load_yaml_config, instantiate_from_config
from Models.interpretable_diffusion.model_utils import unnormalize_to_zero_to_one

# %% [markdown]
# ## Setting and Training

# %% [markdown]
# ### Build dataset and settings

# %%
class Args_Example:
    def __init__(self) -> None:
        self.config_path = './Config/sines.yaml'     # 选择数据集
#         self.config_path = './Config/stocks.yaml'
        self.save_dir = './toy_exp'
        self.gpu = 0
        os.makedirs(self.save_dir, exist_ok=True)

args =  Args_Example()
configs = load_yaml_config(args.config_path)
device = torch.device(f'cuda:{args.gpu}' if torch.cuda.is_available() else 'cpu')


configs['solver']['max_epochs']=10000
configs['dataloader']['batch_size'] = 128
print(configs['model'])
print(configs['solver'])
print(configs['dataloader']['train_dataset'])
print(configs['dataloader']['test_dataset'])
print(configs['dataloader']['batch_size'])
print(configs['dataloader']['sample_size'])
# Out:
# {'target': 'Models.interpretable_diffusion.gaussian_diffusion.Diffusion_TS', 'params': {'seq_length': 24, 'feature_size': 5, 'n_layer_enc': 1, 'n_layer_dec': 2, 'd_model': 64, 'timesteps': 500, 'sampling_timesteps': 500, 'loss_type': 'l1', 'beta_schedule': 'cosine', 'n_heads': 4, 'mlp_hidden_times': 4, 'attn_pd': 0.0, 'resid_pd': 0.0, 'kernel_size': 1, 'padding_size': 0}}
# {'base_lr': 1e-05, 'max_epochs': 10000, 'results_folder': './Checkpoints_sine', 'gradient_accumulate_every': 2, 'save_cycle': 1200, 'ema': {'decay': 0.995, 'update_interval': 10}, 'scheduler': {'target': 'engine.lr_sch.ReduceLROnPlateauWithWarmup', 'params': {'factor': 0.5, 'patience': 3000, 'min_lr': 1e-05, 'threshold': 0.1, 'threshold_mode': 'rel', 'warmup_lr': 0.0008, 'warmup': 500, 'verbose': False}}}
# {'target': 'Utils.Data_utils.sine_dataset.SineDataset', 'params': {'num': 10000, 'dim': 5, 'window': 24, 'save2npy': True, 'neg_one_to_one': True, 'seed': 123, 'period': 'train'}}
# {'target': 'Utils.Data_utils.sine_dataset.SineDataset', 'params': {'num': 1000, 'dim': 5, 'window': 24, 'save2npy': True, 'neg_one_to_one': True, 'seed': 123, 'style': 'separate', 'period': 'test', 'distribution': 'geometric'}, 'coefficient': 0.01, 'step_size': 0.05, 'sampling_steps': 200}
# 128
# 256

# %%
dl_info = build_dataloader(configs, args)   # 此时会把真实数据保存为npy格式
dl = dl_info['dataloader']
print(next(iter(dl)).shape)

ds = dl_info['dataset']
print(len(ds), ds[0].shape)



# def cycle(dl):
#     while True:
#         for data in dl:
#             yield data
# cycle(dl)

# for data in dl:
#     print(data.shape)
# Out:
# Sampling sine-dataset:   0%|          | 0/10000 [00:00<?, ?it/s]
# torch.Size([128, 24, 5])
# 10000 torch.Size([24, 5])

# %%
model = instantiate_from_config(configs['model']).to(device)   # 导入Diffusion_TS
# print(model)

trainer = Trainer(config=configs, args=args, model=model, dataloader=dl_info)
print(trainer.opt)
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: [0.9, 0.96]
#     capturable: False
#     eps: 1e-08
#     foreach: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )

# %% [markdown]
# ### Training models

# %%
trainer.train()
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# training complete

# %% [markdown]
# ## Inference and Visualizations

# %% [markdown]
# ### Sampling

# %%
dataset = dl_info['dataset']
seq_length, feature_dim = dataset.window, dataset.var_num
print(seq_length, feature_dim, dataset.dir, len(dataset), dataset.auto_norm )
# Out:
# 24 5 ./toy_exp\samples 10000 True

# %%
ori_data = np.load(os.path.join( dataset.dir, f"sine_ground_truth_{seq_length}_train.npy" ))

# ori_data = np.load(os.path.join(dataset.dir, f"{'stock'}_norm_truth_{seq_length}_train.npy"))
print(ori_data.shape)
# Out:
# (10000, 24, 5)

# %%
sample = trainer.ema.ema_model.generate_mts(batch_size=10000)  # Diffusion_TS模块里的generate_mts

torch.cuda.empty_cache()
    
fake_data = sample.detach().cpu().numpy()
# Out:
# sampling loop time step:   0%|          | 0/500 [00:00<?, ?it/s]

# %%
'这个反归一化对pca有影响 要使用 '
'只能用一次 不然pca效果变差 因为生成数据不对了'
if dataset.auto_norm:
    fake_data = unnormalize_to_zero_to_one(fake_data)
    np.save(os.path.join(args.save_dir, f'ddpm_fake_sines.npy'), fake_data)

# %% [markdown]
# ### Visualization
#
# We visualize the original and synthetic data distributions using PCA, tSNE and Density analysis.

# %%
visualization(ori_data=ori_data, generated_data=fake_data, analysis='pca', compare=ori_data.shape[0])

# %%
visualization(ori_data=ori_data, generated_data=fake_data, analysis='tsne', compare=ori_data.shape[0])
# Out:
# C:\Users\PC123\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 20000 samples in 0.001s...
# [t-SNE] Computed neighbors for 20000 samples in 0.429s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 20000
# [t-SNE] Computed conditional probabilities for sample 2000 / 20000
# [t-SNE] Computed conditional probabilities for sample 3000 / 20000
# [t-SNE] Computed conditional probabilities for sample 4000 / 20000
# [t-SNE] Computed conditional probabilities for sample 5000 / 20000
# [t-SNE] Computed conditional probabilities for sample 6000 / 20000
# [t-SNE] Computed conditional probabilities for sample 7000 / 20000
# [t-SNE] Computed conditional probabilities for sample 8000 / 20000
# [t-SNE] Computed conditional probabilities for sample 9000 / 20000
# [t-SNE] Computed conditional probabilities for sample 10000 / 20000
# [t-SNE] Computed conditional probabilities for sample 11000 / 20000
# [t-SNE] Computed conditional probabilities for sample 12000 / 20000
# [t-SNE] Computed conditional probabilities for sample 13000 / 20000
# [t-SNE] Computed conditional probabilities for sample 14000 / 20000
# [t-SNE] Computed conditional probabilities for sample 15000 / 20000
# [t-SNE] Computed conditional probabilities for sample 16000 / 20000
# [t-SNE] Computed conditional probabilities for sample 17000 / 20000
# [t-SNE] Computed conditional probabilities for sample 18000 / 20000
# [t-SNE] Computed conditional probabilities for sample 19000 / 20000
# [t-SNE] Computed conditional probabilities for sample 20000 / 20000
# [t-SNE] Mean sigma: 0.007637
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.057816
# [t-SNE] KL divergence after 300 iterations: 2.700225

# %%
visualization(ori_data=ori_data, generated_data=fake_data, analysis='kernel', compare=ori_data.shape[0])
# Out:
# C:\Users\PC123\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\PC123\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
import importlib

target= 'Models.interpretable_diffusion.gaussian_diffusion.Diffusion_TS'
module, cls = target.rsplit(".", 1)
print(module,cls)

cls = getattr(importlib.import_module(module, package=None), cls)
print(cls)
# Out:
# Models.interpretable_diffusion.gaussian_diffusion Diffusion_TS
# <class 'Models.interpretable_diffusion.gaussian_diffusion.Diffusion_TS'>
