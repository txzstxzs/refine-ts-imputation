# %%
import os
import torch
import argparse
import numpy as np

from engine.logger import Logger
from engine.solver import Trainer
from Data.build_dataloader import build_dataloader, build_dataloader_cond
from Models.interpretable_diffusion.model_utils import unnormalize_to_zero_to_one
from Utils.io_utils import load_yaml_config, seed_everything, merge_opts_to_config, instantiate_from_config
from Utils.metric_utils import visualization

import sys
import time
import torch.nn as nn
import torch.nn.functional as F

from pathlib import Path
from tqdm import tqdm
from ema_pytorch import EMA
from torch.optim import Adam
from torch.nn.utils import clip_grad_norm_
from Utils.io_utils import instantiate_from_config, get_model_parameters_info


from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
plt.rc('font',family='Times New Roman') # 设置全局字体

import umap                         # 注意版本对应 numba0.56.4到0.58.1 对应 numpy1.23.4
import seaborn as sns 

from pypots.utils.metrics import calc_mse,calc_rmse,calc_mae
import random
# Out:
# 2025-07-29 19:50:54 [WARNING]: ‼️ `pypots.utils.metrics` is deprecated. Please import from `pypots.nn.functional` instead.
# ████████╗██╗███╗   ███╗███████╗    ███████╗███████╗██████╗ ██╗███████╗███████╗    █████╗ ██╗
# ╚══██╔══╝██║████╗ ████║██╔════╝    ██╔════╝██╔════╝██╔══██╗██║██╔════╝██╔════╝   ██╔══██╗██║
#    ██║   ██║██╔████╔██║█████╗█████╗███████╗█████╗  ██████╔╝██║█████╗  ███████╗   ███████║██║
#    ██║   ██║██║╚██╔╝██║██╔══╝╚════╝╚════██║██╔══╝  ██╔══██╗██║██╔══╝  ╚════██║   ██╔══██║██║
#    ██║   ██║██║ ╚═╝ ██║███████╗    ███████║███████╗██║  ██║██║███████╗███████║██╗██║  ██║██║
#    ╚═╝   ╚═╝╚═╝     ╚═╝╚══════╝    ╚══════╝╚══════╝╚═╝  ╚═╝╚═╝╚══════╝╚══════╝╚═╝╚═╝  ╚═╝╚═╝
# ai4ts v0.0.3 - building AI for unified time-series analysis, https://time-series.ai

# %%
def visualization2(ori, gen):
    
    Number = ori.shape[0]
    
    max_sample = min([4000, Number])       # 最多取4000个样本
    idx = np.random.permutation(Number)[ :max_sample]

    ori1 = np.asarray(ori)[idx]
    gen1 = np.asarray(gen)[idx]

    ori1 = np.mean(ori1, 2) 
    gen1 = np.mean(gen1, 2) 


    '上部分为原样本 下部分为生成样本'
    concat_data = np.concatenate((ori1, gen1), axis=0)
    
    pca = PCA(2)     
    pca_res = pca.fit_transform(concat_data)

    tsne = TSNE(n_components=2, verbose=1, perplexity=40,random_state=20,n_iter=500) 
    tsne_res = tsne.fit_transform(concat_data) 

    umap_ = umap.UMAP(random_state=42)
    umap_res = umap_.fit_transform(concat_data)
    
    
    fig = plt.figure(figsize=(19,4))
    plt.subplot(1,4,1)
    
    '0到2000索引的为原样本'
    plt.scatter(pca_res[:2000,0],pca_res[:2000,1], s=15, c='#ff7f0e')
    plt.scatter(pca_res[max_sample:max_sample+2000,0],pca_res[max_sample:max_sample+2000,1], s=15, c='#1f77b4')
    plt.xlabel('(a)',fontsize=25)
    
    plt.subplot(1,4,2)
    plt.scatter(tsne_res[:2000,0],tsne_res[:2000,1],  s=15,  c='#ff7f0e')
    plt.scatter(tsne_res[max_sample:max_sample+2000,0],tsne_res[max_sample:max_sample+2000,1], s=15, c='#1f77b4')
    plt.xlabel('(b)',fontsize=25)

    plt.subplot(1,4,3)
    plt.scatter(umap_res[:2000, 0], umap_res[:2000, 1],  cmap='Spectral', s=15,  c='#ff7f0e')
    plt.scatter(umap_res[max_sample:max_sample+2000, 0], umap_res[max_sample:max_sample+2000, 1],  cmap='Spectral', s=15, c='#1f77b4')
    plt.xlabel('(c)',fontsize=25)

    
    plt.subplot(1,4,4)
    sns.distplot(ori[:,:,1], hist=False, color = '#ff7f0e' )
    sns.distplot(gen[:,:,1], hist=False, color = '#1f77b4' )  
    plt.xlabel('(d)',fontsize=25)
    
    
#     plt.savefig('pca等合成图1111',dpi=500, bbox_inches='tight' )
#     plt.savefig('pca等合成图_sp5001111.pdf', bbox_inches='tight')

# %%
def parse_args():
    parser = argparse.ArgumentParser(description='PyTorch Training Script')
    parser.add_argument('--name', type=str, default=None)

    parser.add_argument('--config_file', type=str, default=None, 
                        help='path of config file')
    parser.add_argument('--output', type=str, default='OUTPUT', 
                        help='directory to save the results')
    parser.add_argument('--tensorboard', action='store_true', 
                        help='use tensorboard for logging')

    # args for random

    parser.add_argument('--cudnn_deterministic', action='store_true', default=False,
                        help='set cudnn.deterministic True')
    parser.add_argument('--seed', type=int, default=10, 
                        help='seed for initializing training.')
    parser.add_argument('--gpu', type=int, default=None,
                        help='GPU id to use. If given, only the specific gpu will be'
                        ' used, and ddp will be disabled')
    
    # args for training
    parser.add_argument('--train', action='store_true', default=False, help='Train or Test.')
    parser.add_argument('--sample', type=int, default=0, 
                        choices=[0, 1], help='Condition or Uncondition.')
    parser.add_argument('--mode', type=str, default='infill',
                        help='Infilling or Forecasting.')
    parser.add_argument('--milestone', type=int, default=10)

    parser.add_argument('--missing_ratio', type=float, default=0., help='Ratio of Missing Values.')
    parser.add_argument('--pred_len', type=int, default=0, help='Length of Predictions.')
    
    
    # args for modify config
    parser.add_argument('opts', help='Modify config options using the command-line',
                        default=None, nargs=argparse.REMAINDER)  

    args = parser.parse_args(args=[])
    args.save_dir = os.path.join(args.output, f'{args.name}')

    return args

# %%
args = parse_args()

# data_name = 'SP500'
# data_name = 'ETTh1'
# data_name = 'Energy'
data_name = 'exchange_rate'
# data_name = 'weather'

# data_name = 'MuJoCo'
# data_name = 'fmri'

if data_name == 'SP500':
    args.config_file =  './Config/SP500.yaml'
    
elif data_name == 'ETTh1':
    args.config_file =  './Config/ETTh1.yaml'

elif data_name == 'Energy':
    args.config_file =  './Config/Energy.yaml'
    
elif data_name == 'MuJoCo':
    args.config_file =  './Config/MuJoCo.yaml'
    
elif data_name == 'fmri':
    args.config_file =  './Config/fmri.yaml'

elif data_name == 'exchange_rate':
    args.config_file =  './Config/exchange_rate.yaml'
    
elif data_name == 'weather':
    args.config_file =  './Config/weather.yaml'
    
    
# args.config_file =  './Config/stocks.yaml'

args.gpu =  0
args.train = True
print(args)
# Out:
# Namespace(name=None, config_file='./Config/exchange_rate.yaml', output='OUTPUT', tensorboard=False, cudnn_deterministic=False, seed=10, gpu=0, train=True, sample=0, mode='infill', milestone=10, missing_ratio=0.0, pred_len=0, opts=[], save_dir='OUTPUT\\None')

# %%
if args.seed is not None:
    seed_everything(args.seed)

if args.gpu is not None:
    torch.cuda.set_device(args.gpu)

config = load_yaml_config(args.config_file)
config = merge_opts_to_config(config, args.opts)


config['dataloader']['batch_size'] = 128
print(config)

beta_schedule = config['model']['params']['beta_schedule'] 
timesteps = config['model']['params']['timesteps'] 
print(beta_schedule, timesteps)
# Out:
# Global seed set to 10
# {'model': {'target': 'Models.interpretable_diffusion.gaussian_diffusion.Diffusion_TS', 'params': {'seq_length': 24, 'feature_size': 8, 'n_layer_enc': 4, 'n_layer_dec': 3, 'd_model': 96, 'timesteps': 500, 'sampling_timesteps': 500, 'loss_type': 'l1', 'beta_schedule': 'cosine', 'n_heads': 4, 'mlp_hidden_times': 4, 'attn_pd': 0.0, 'resid_pd': 0.0, 'kernel_size': 1, 'padding_size': 0}}, 'solver': {'base_lr': 1e-05, 'max_epochs': 25000, 'results_folder': './Checkpoints_energy', 'gradient_accumulate_every': 2, 'save_cycle': 2500, 'ema': {'decay': 0.995, 'update_interval': 10}, 'scheduler': {'target': 'engine.lr_sch.ReduceLROnPlateauWithWarmup', 'params': {'factor': 0.5, 'patience': 5000, 'min_lr': 1e-05, 'threshold': 0.1, 'threshold_mode': 'rel', 'warmup_lr': 0.0008, 'warmup': 500, 'verbose': False}}}, 'dataloader': {'train_dataset': {'target': 'Utils.Data_utils.real_datasets.CustomDataset', 'params': {'name': 'energy', 'proportion': 1.0, 'data_root': './Data/datasets/energy_data.csv', 'window': 24, 'save2npy': True, 'neg_one_to_one': True, 'seed': 123, 'period': 'train'}}, 'test_dataset': {'target': 'Utils.Data_utils.real_datasets.CustomDataset', 'params': {'name': 'energy', 'proportion': 0.9, 'data_root': './Data/datasets/energy_data.csv', 'window': 24, 'save2npy': True, 'neg_one_to_one': True, 'seed': 123, 'period': 'test', 'style': 'separate', 'distribution': 'geometric'}, 'coefficient': 0.01, 'step_size': 0.05, 'sampling_steps': 250}, 'batch_size': 128, 'sample_size': 256, 'shuffle': True}}
# cosine 500

# %%
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

if data_name == 'SP500':
    load_data = np.load( './Data/datasets/sp500.npy')

elif data_name == 'ETTh1':
    load_data = np.load( './Data/datasets/ETTh1.npy')
    
elif data_name == 'Energy':
    load_data = np.load( './Data/datasets/Energy.npy')

elif data_name == 'MuJoCo':
    load_data = np.load( './Data/datasets/MuJoCo.npy')
    
elif data_name == 'fmri':
    load_data = np.load( './Data/datasets/fmri.npy')
    
elif data_name == 'exchange_rate':
    load_data = np.load( './Data/datasets/exchange_rate.npy')
    
elif data_name == 'weather':
    load_data = np.load( './Data/datasets/weather.npy')
    
    
    
    
np.random.shuffle(load_data)
 
print(load_data.shape)

Numble = load_data.shape[0]
Length = load_data.shape[1]
Feature = load_data.shape[2]
   
shape = (Numble, Length, Feature)
print(shape)
# Out:
# (2522, 24, 8)
# (2522, 24, 8)

# %%
def default(val, d):
    if exists(val):
        return val
    return d() if callable(d) else d

def exists(x):
    return x is not None

from Models.interpretable_diffusion.model_utils import default, identity, extract
from Models.interpretable_diffusion.gaussian_diffusion import linear_beta_schedule, cosine_beta_schedule, Diffusion_TS
import torch.nn.functional as F

# num_timesteps = model.num_timesteps
# print(num_timesteps)

# %% [markdown]
# # load shortcut

# %%
shortcut = instantiate_from_config(config['model']).cuda()

# %%
device = shortcut.betas.device

# %%
start_lr = config['solver'].get('base_lr', 1.0e-4)
ema_decay = config['solver']['ema']['decay']
ema_update_every = config['solver']['ema']['update_interval']
ema = EMA(shortcut, beta=ema_decay, update_every=ema_update_every).to(device)

opt = Adam(filter(lambda p: p.requires_grad, shortcut.parameters()), lr=start_lr, betas=[0.9, 0.96])
sc_cfg = config['solver']['scheduler']
sc_cfg['params']['optimizer'] = opt    # 配置里添加了一个优化器参数
sch = instantiate_from_config(sc_cfg)   # 导入了 engine.lr_sch.ReduceLROnPlateauWithWarmup

# %%
ds = 1 / torch.tensor([2 ** i for i in range(1, 8)]).to(device)
ds_p = torch.ones((ds.shape[0],)).to(device) / ds.shape[0]

d = ds[ds_p.multinomial(5, replacement=True).to(device)]
print(d, d.shape)

t = torch.rand(size=(10, 1), device=device)
print(t,t.shape)


def reshape_coefs(t):
    return t.reshape((t.shape[0], 1,  1))
# Out:
# tensor([0.0078, 0.2500, 0.0156, 0.5000, 0.0312], device='cuda:0') torch.Size([5])
# tensor([[0.4674],
#         [0.2601],
#         [0.3044],
#         [0.9964],
#         [0.8242],
#         [0.1826],
#         [0.8790],
#         [0.6630],
#         [0.9736],
#         [0.1960]], device='cuda:0') torch.Size([10, 1])

# %%
padding_masks = None
clip_x_start = False
clip_denoised = True

# %%
shortcut = instantiate_from_config(config['model']).cuda()

# shortcut.load_state_dict(torch.load( "./checkpoint/shortcut/sp500_shortcut.pth"  ))
# ema.load_state_dict(torch.load( "./checkpoint/shortcut/sp500_ema_shortcut.pth"  ))

# shortcut.load_state_dict(torch.load( "./checkpoint/shortcut/ETTh1_shortcut.pth"  ))
# ema.load_state_dict(torch.load( "./checkpoint/shortcut/ETTh1_ema_shortcut.pth"  ))

# shortcut.load_state_dict(torch.load( "./checkpoint/shortcut/Energy_shortcut.pth"  ))
# ema.load_state_dict(torch.load( "./checkpoint/shortcut/Energy_ema_shortcut.pth"  ))

# shortcut.load_state_dict(torch.load( "./checkpoint/shortcut/MuJoCo_shortcut.pth"  ))
# ema.load_state_dict(torch.load( "./checkpoint/shortcut/MuJoCo_ema_shortcut.pth"  ))

# shortcut.load_state_dict(torch.load( "./checkpoint/shortcut/fmri_shortcut.pth"  ))
# ema.load_state_dict(torch.load( "./checkpoint/shortcut/fmri_ema_shortcut.pth"  ))


shortcut.load_state_dict(torch.load( "./checkpoint/shortcut/exchange_rate_shortcut.pth"  ))
ema.load_state_dict(torch.load( "./checkpoint/shortcut/exchange_rate_ema_shortcut.pth"  ))


# shortcut.load_state_dict(torch.load( "./checkpoint/shortcut/weather_shortcut.pth"  ))
# ema.load_state_dict(torch.load( "./checkpoint/shortcut/weather_ema_shortcut.pth"  ))
# Out:
# <All keys matched successfully>

# %%
n_steps = 20
eps = 1e-8
# eps = 0
shape = (Numble, Length, Feature)


x_t = torch.randn(shape, device=device)
b, c, n, = x_t.shape

padding_masks = torch.ones(b, c, dtype=bool, device=device)


d = torch.tensor(1 / n_steps).to(device)
t = torch.linspace(eps, 1 - eps, n_steps+1 ).to(device)
# print(len(t))

for i in range(1, len(t)):
    t_batch = t[ i-1 ].unsqueeze(0).repeat((b,))
    d_batch = d.unsqueeze(0).repeat((b,))
    
    
    with torch.no_grad():
        
        v_pred = ema.ema_model.output(x_t, t_batch, d=d_batch, padding_masks=padding_masks) 

    x_t = x_t + (t[i] - t[i - 1]) * v_pred
    

print( t_batch.shape, d_batch.shape )
print(x_t.shape)
# Out:
# torch.Size([2522]) torch.Size([2522])
# torch.Size([2522, 24, 8])

# %%
visualization(ori_data=load_data, generated_data=x_t.detach().cpu().numpy(), analysis='pca', compare=load_data.shape[0])

# %%
# visualization2(train_data, x_t.detach().cpu().numpy() )

# %% [markdown]
# # 二阶欧拉采样

# %%
n_steps = 10
eps = 1e-8
# eps = 0
shape = (Numble, Length, Feature)

x_t = torch.randn(shape, device=device)
b, c, n, = x_t.shape

padding_masks = torch.ones(b, c, dtype=bool, device=device)


d = torch.tensor(1 / n_steps).to(device)
t = torch.linspace(eps, 1 - eps, n_steps+1 ).to(device)
# t = torch.linspace(0, 1 , n_steps+1 ).to(device)

for i in range(1, len(t)):
    t_batch = t[ i-1 ].unsqueeze(0).repeat((b,))
    d_batch = d.unsqueeze(0).repeat((b,))
    
    with torch.no_grad():
        
        v_pred = ema.ema_model.output(x_t, t_batch, d=d_batch, padding_masks=padding_masks) 

        x_t_p_dt = x_t + (t[i] - t[i - 1]) * v_pred
        
        t_batch = t[i].unsqueeze(0).repeat((b,))
        
        v_pred_p_dt = ema.ema_model.output(x_t_p_dt, t_batch, d=d_batch, padding_masks=padding_masks) 
        
        v_deriv = (v_pred_p_dt - v_pred)/(t[i] - t[i - 1])
        
    
    x_t = x_t + (t[i] - t[i - 1]) * v_pred  + ( 0.5 *  (t[i] - t[i - 1])**2)  * v_deriv


print( t_batch.shape, d_batch.shape )
print(x_t.shape)
# Out:
# torch.Size([5775]) torch.Size([5775])
# torch.Size([5775, 30, 6])

# %%
# visualization(ori_data=train_data, generated_data=x_t.detach().cpu().numpy(), analysis='pca', compare=train_data.shape[0])

# %%
# visualization2(train_data, x_t.detach().cpu().numpy() )

# %% [markdown]
# # 补全

# %%
from torch.autograd import Variable

def get_mask_mcar(sample, mr): 
    mask = torch.ones(sample.shape).view(1,-1) 
    index = torch.tensor(range(mask.shape[1]))  
    perm = torch.randperm(len(index)) 
    index = perm[ 0: round( mr*len(index) ) ]
    mask[0][index]=0
    mask = mask.view(sample.shape)
    return mask


def get_mask_mnr(sample, k):  # 缺失的时候是连续k个点一起缺失 不那么随机 
    mask = torch.ones(sample.shape)
    length_index = torch.tensor(range(mask.shape[0]))
    list_of_segments_index = torch.split(length_index, k)
    for channel in range(mask.shape[1]):
        s_nan = random.choice(list_of_segments_index)
        mask[:, channel][s_nan[0]:s_nan[-1] + 1] = 0

    return mask


def get_mask_bm(sample, k):  # 和上面的类似 也是连续缺失 而且每一列的缺失情况都一样 也就是块缺失
    mask = torch.ones(sample.shape)
    length_index = torch.tensor(range(mask.shape[0]))
    list_of_segments_index = torch.split(length_index, k)
    s_nan = random.choice(list_of_segments_index)
    for channel in range(mask.shape[1]):
        mask[:, channel][s_nan[0]:s_nan[-1] + 1] = 0

    return mask


print( load_data.shape )
# Out:
# (2522, 24, 8)

# %% [markdown]
# # 使用逆推码

# %%
'rmse结果和初始隐码关系恨到 初始隐码越好 rmse越小'
'一个方法是增加采样步 使得逆推码变好'
'有个现象 若初始隐码还原结果的rmse为a 训练后稳定的rmse为a-0.1  就是优化法能减小的rmse为0.01左右'
'另一个方法是改变逆推方法 提高逆推后重构的精确度'
'第三个方法应该是用一个好得预补全方法 得到好的初始值和逆推码'

'有一个结论就是 优化法有极限 不同的初始逆推码 难以优化到同一个近似结果 需要通过更好的预补全 更好的逆推法 来得到更好的逆推码'

'总之 初始值 初始隐码 影响很大 '
'感觉好像更新时 只有观测处在更新 缺失处不怎么更新'


target = torch.tensor( load_data ).float().cuda()
shape = target.shape
print(shape)
b, c, n, = target.shape

padding_masks = torch.ones(b, c, dtype=bool, device=device)
# Out:
# torch.Size([2522, 24, 8])

# %% [markdown]
# # choose missing rate, mechanism and pre-imputation model

# %%
mr = 0.6
# mechanism = 'mcar'  
mechanism = 'mnr' 
missing_length = int( mr * Length )
print(mr, missing_length)

pre_imputation = 'SAITS'
# pre_imputation = 'Pyraformer'
# pre_imputation = 'ImputeFormer'
# pre_imputation = 'csdi'
# Out:
# 0.6 14

# %% [markdown]
# # make train dataset
# # exert artificial missing
# # treat train_data as samples with missing values represented by nan

# %%
Mask = torch.empty([0, c, n])    
print( Mask.shape)

for i in range(target.shape[0]):
    if mechanism == 'mcar':
        one_mask = get_mask_mcar( target[0], mr)  
    else:
        one_mask = get_mask_mnr( target[0], missing_length) 

    one_mask = one_mask.unsqueeze(0)   
    Mask = torch.row_stack([Mask, one_mask])

Mask = Mask.float().cuda()
train_data = target * Mask
train_data[train_data == 0] = np.nan
train_set = {"X": train_data}

print( Mask.shape )
# Out:
# torch.Size([0, 24, 8])
# torch.Size([2522, 24, 8])

# %% [markdown]
# # make test dataset

# %%
Mask_test = torch.empty([0, c, n])    
for i in range(target.shape[0]):
    if mechanism == 'mcar':
        one_mask = get_mask_mcar( target[0], mr)  
    else:
        one_mask = get_mask_mnr( target[0], missing_length) 

    one_mask = one_mask.unsqueeze(0)   
    Mask_test = torch.row_stack([Mask_test, one_mask])
    
Mask_test = Mask_test.float().cuda()
print( Mask_test.shape )


test_data = target * Mask_test
test_data[test_data == 0] = np.nan
test_set =  {"X": test_data}
print(mr, mechanism)
# Out:
# torch.Size([2522, 24, 8])
# 0.6 mnr

# %% [markdown]
# # start pre-imputation

# %%
from pypots.imputation import Pyraformer
from pypots.imputation import SAITS  
from pypots.imputation import ImputeFormer
from pypots.imputation import Informer
from pypots.imputation import CSDI
from pypots.imputation import ETSformer
from pypots.optim import Adam

# %%
if pre_imputation == 'Pyraformer':
    pyraformer = Pyraformer( 
        n_steps = train_data.shape[1], n_features = train_data.shape[2],
        n_layers= 4, n_heads = 4,
        d_model = 256, d_ffn = 512,
        window_size = [1, 1, 1],
        inner_size = 3,
        dropout = 0.1,
        batch_size=200, epochs=1000,  )

    pyraformer.fit( train_set = train_set  )

    
elif pre_imputation == 'SAITS':
    saits = SAITS(n_steps=train_data.shape[1], n_features=train_data.shape[2],
                  n_layers=2, d_model=256, n_heads=4, d_k=64, d_v=64, d_ffn=128, dropout=0.1, 
    #               n_layers=2, d_model=256, n_heads=4, d_k=128, d_v=128, d_ffn=128, dropout=0.1,  # mujoco要增加参数
                  num_workers=0, optimizer=Adam(lr=1e-3), 
                  batch_size=200, epochs=800, )

    saits.fit( train_set = train_set) 
    
    
elif pre_imputation == 'ImputeFormer':
    imputeFormer = ImputeFormer( 
    n_steps = train_data.shape[1], n_features = train_data.shape[2],
    n_layers=4,
    d_input_embed= 24, d_learnable_embed=128,     
    d_proj= 36,  d_ffn=256, 
    n_temporal_heads=4, 
    ORT_weight=1, MIT_weight=1,
    batch_size=200, epochs=400,  )
    
    imputeFormer.fit( train_set = train_set  )
    
    
elif pre_imputation == 'Informer':
    informer = Informer( 
    n_steps = train_data.shape[1], n_features = train_data.shape[2],
    n_layers=4, n_heads=8,
    d_model=256, d_ffn=512,
    factor=5,
    batch_size=200, epochs=400,  )
    
    informer.fit( train_set = train_set  )
    
    
elif pre_imputation == 'etsformer':
    eTSformer = ETSformer( 
        n_steps = train_data.shape[1], n_features = train_data.shape[2],
        n_heads=8,
        d_model=256, d_ffn=512,
        top_k=1,
        n_encoder_layers=2, n_decoder_layers=2,
        batch_size=200, epochs=1000,  )
    
    eTSformer.fit( train_set = train_set  )
    
    
    
elif pre_imputation == 'csdi':
    csdi = CSDI(
        n_steps= train_data.shape[1], n_features= train_data.shape[2],
        n_layers=6, n_heads=2, n_channels=128,
        d_time_embedding=64, d_feature_embedding=32, d_diffusion_embedding=128,
        target_strategy="random",
        n_diffusion_steps=50,
        batch_size=200,              # mujoco用150 不然显存不够
        epochs=200,
        optimizer=Adam(lr=1e-3),
        num_workers=0, )
    
    csdi.fit( train_set = train_set )
# Out:
# 2025-07-29 19:51:42 [INFO]: No given device, using default device: cuda
# 2025-07-29 19:51:42 [WARNING]: ‼️ saving_path not given. Model files and tensorboard file will not be saved.
# 2025-07-29 19:51:42 [INFO]: Using customized MAE as the training loss function.
# 2025-07-29 19:51:42 [INFO]: Using customized MSE as the validation metric function.
# 2025-07-29 19:51:42 [INFO]: SAITS initialized with the given hyperparameters, the number of trainable parameters: 1,329,504
# 2025-07-29 19:51:43 [INFO]: Epoch 001 - training loss (MAE): 0.6651
# 2025-07-29 19:51:44 [INFO]: Epoch 002 - training loss (MAE): 0.4643
# 2025-07-29 19:51:45 [INFO]: Epoch 003 - training loss (MAE): 0.3930
# 2025-07-29 19:51:46 [INFO]: Epoch 004 - training loss (MAE): 0.3347
# 2025-07-29 19:51:47 [INFO]: Epoch 005 - training loss (MAE): 0.2996
# 2025-07-29 19:51:48 [INFO]: Epoch 006 - training loss (MAE): 0.2710
# 2025-07-29 19:51:49 [INFO]: Epoch 007 - training loss (MAE): 0.2481
# 2025-07-29 19:51:50 [INFO]: Epoch 008 - training loss (MAE): 0.2376
# 2025-07-29 19:51:51 [INFO]: Epoch 009 - training loss (MAE): 0.2211
# 2025-07-29 19:51:52 [INFO]: Epoch 010 - training loss (MAE): 0.2146
# 2025-07-29 19:51:53 [INFO]: Epoch 011 - training loss (MAE): 0.2017
# 2025-07-29 19:51:54 [INFO]: Epoch 012 - training loss (MAE): 0.1947
# 2025-07-29 19:51:54 [INFO]: Epoch 013 - training loss (MAE): 0.1866
# 2025-07-29 19:51:56 [INFO]: Epoch 014 - training loss (MAE): 0.1821
# 2025-07-29 19:51:56 [INFO]: Epoch 015 - training loss (MAE): 0.1693
# 2025-07-29 19:51:57 [INFO]: Epoch 016 - training loss (MAE): 0.1654
# 2025-07-29 19:51:58 [INFO]: Epoch 017 - training loss (MAE): 0.1596
# 2025-07-29 19:51:59 [INFO]: Epoch 018 - training loss (MAE): 0.1486
# 2025-07-29 19:52:00 [INFO]: Epoch 019 - training loss (MAE): 0.1450
# 2025-07-29 19:52:01 [INFO]: Epoch 020 - training loss (MAE): 0.1441
# 2025-07-29 19:52:02 [INFO]: Epoch 021 - training loss (MAE): 0.1374
# 2025-07-29 19:52:03 [INFO]: Epoch 022 - training loss (MAE): 0.1318
# 2025-07-29 19:52:04 [INFO]: Epoch 023 - training loss (MAE): 0.1294
# 2025-07-29 19:52:05 [INFO]: Epoch 024 - training loss (MAE): 0.1245
# 2025-07-29 19:52:06 [INFO]: Epoch 025 - training loss (MAE): 0.1244
# 2025-07-29 19:52:07 [INFO]: Epoch 026 - training loss (MAE): 0.1186
# 2025-07-29 19:52:08 [INFO]: Epoch 027 - training loss (MAE): 0.1168
# 2025-07-29 19:52:09 [INFO]: Epoch 028 - training loss (MAE): 0.1158
# 2025-07-29 19:52:10 [INFO]: Epoch 029 - training loss (MAE): 0.1122
# 2025-07-29 19:52:11 [INFO]: Epoch 030 - training loss (MAE): 0.1094
# 2025-07-29 19:52:12 [INFO]: Epoch 031 - training loss (MAE): 0.1066
# 2025-07-29 19:52:13 [INFO]: Epoch 032 - training loss (MAE): 0.1071
# 2025-07-29 19:52:14 [INFO]: Epoch 033 - training loss (MAE): 0.1024
# 2025-07-29 19:52:15 [INFO]: Epoch 034 - training loss (MAE): 0.1027
# 2025-07-29 19:52:16 [INFO]: Epoch 035 - training loss (MAE): 0.1018
# 2025-07-29 19:52:17 [INFO]: Epoch 036 - training loss (MAE): 0.1000
# 2025-07-29 19:52:18 [INFO]: Epoch 037 - training loss (MAE): 0.0990
# 2025-07-29 19:52:18 [INFO]: Epoch 038 - training loss (MAE): 0.0979
# 2025-07-29 19:52:19 [INFO]: Epoch 039 - training loss (MAE): 0.0979
# 2025-07-29 19:52:20 [INFO]: Epoch 040 - training loss (MAE): 0.0978
# 2025-07-29 19:52:21 [INFO]: Epoch 041 - training loss (MAE): 0.0957
# 2025-07-29 19:52:22 [INFO]: Epoch 042 - training loss (MAE): 0.0950
# 2025-07-29 19:52:23 [INFO]: Epoch 043 - training loss (MAE): 0.0967
# 2025-07-29 19:52:24 [INFO]: Epoch 044 - training loss (MAE): 0.0927
# 2025-07-29 19:52:25 [INFO]: Epoch 045 - training loss (MAE): 0.0900
# 2025-07-29 19:52:26 [INFO]: Epoch 046 - training loss (MAE): 0.0901
# 2025-07-29 19:52:27 [INFO]: Epoch 047 - training loss (MAE): 0.0911
# 2025-07-29 19:52:28 [INFO]: Epoch 048 - training loss (MAE): 0.0906
# 2025-07-29 19:52:29 [INFO]: Epoch 049 - training loss (MAE): 0.0903
# 2025-07-29 19:52:30 [INFO]: Epoch 050 - training loss (MAE): 0.0873
# 2025-07-29 19:52:31 [INFO]: Epoch 051 - training loss (MAE): 0.0860
# 2025-07-29 19:52:32 [INFO]: Epoch 052 - training loss (MAE): 0.0852
# 2025-07-29 19:52:33 [INFO]: Epoch 053 - training loss (MAE): 0.0852
# 2025-07-29 19:52:34 [INFO]: Epoch 054 - training loss (MAE): 0.0839
# 2025-07-29 19:52:35 [INFO]: Epoch 055 - training loss (MAE): 0.0838
# 2025-07-29 19:52:36 [INFO]: Epoch 056 - training loss (MAE): 0.0818
# 2025-07-29 19:52:37 [INFO]: Epoch 057 - training loss (MAE): 0.0816
# 2025-07-29 19:52:38 [INFO]: Epoch 058 - training loss (MAE): 0.0806
# 2025-07-29 19:52:39 [INFO]: Epoch 059 - training loss (MAE): 0.0815
# 2025-07-29 19:52:40 [INFO]: Epoch 060 - training loss (MAE): 0.0810
# 2025-07-29 19:52:41 [INFO]: Epoch 061 - training loss (MAE): 0.0797
# 2025-07-29 19:52:42 [INFO]: Epoch 062 - training loss (MAE): 0.0802
# 2025-07-29 19:52:43 [INFO]: Epoch 063 - training loss (MAE): 0.0799
# 2025-07-29 19:52:44 [INFO]: Epoch 064 - training loss (MAE): 0.0792
# 2025-07-29 19:52:45 [INFO]: Epoch 065 - training loss (MAE): 0.0778
# 2025-07-29 19:52:46 [INFO]: Epoch 066 - training loss (MAE): 0.0773
# 2025-07-29 19:52:47 [INFO]: Epoch 067 - training loss (MAE): 0.0763
# 2025-07-29 19:52:48 [INFO]: Epoch 068 - training loss (MAE): 0.0769
# 2025-07-29 19:52:49 [INFO]: Epoch 069 - training loss (MAE): 0.0762
# 2025-07-29 19:52:49 [INFO]: Epoch 070 - training loss (MAE): 0.0764
# 2025-07-29 19:52:50 [INFO]: Epoch 071 - training loss (MAE): 0.0766
# 2025-07-29 19:52:51 [INFO]: Epoch 072 - training loss (MAE): 0.0779
# 2025-07-29 19:52:52 [INFO]: Epoch 073 - training loss (MAE): 0.0762
# 2025-07-29 19:52:53 [INFO]: Epoch 074 - training loss (MAE): 0.0752
# 2025-07-29 19:52:54 [INFO]: Epoch 075 - training loss (MAE): 0.0728
# 2025-07-29 19:52:55 [INFO]: Epoch 076 - training loss (MAE): 0.0733
# 2025-07-29 19:52:56 [INFO]: Epoch 077 - training loss (MAE): 0.0731
# 2025-07-29 19:52:57 [INFO]: Epoch 078 - training loss (MAE): 0.0718
# 2025-07-29 19:52:58 [INFO]: Epoch 079 - training loss (MAE): 0.0718
# 2025-07-29 19:52:59 [INFO]: Epoch 080 - training loss (MAE): 0.0718
# 2025-07-29 19:53:00 [INFO]: Epoch 081 - training loss (MAE): 0.0714
# 2025-07-29 19:53:01 [INFO]: Epoch 082 - training loss (MAE): 0.0735
# 2025-07-29 19:53:02 [INFO]: Epoch 083 - training loss (MAE): 0.0713
# 2025-07-29 19:53:03 [INFO]: Epoch 084 - training loss (MAE): 0.0697
# 2025-07-29 19:53:04 [INFO]: Epoch 085 - training loss (MAE): 0.0691
# 2025-07-29 19:53:05 [INFO]: Epoch 086 - training loss (MAE): 0.0700
# 2025-07-29 19:53:06 [INFO]: Epoch 087 - training loss (MAE): 0.0697
# 2025-07-29 19:53:07 [INFO]: Epoch 088 - training loss (MAE): 0.0695
# 2025-07-29 19:53:08 [INFO]: Epoch 089 - training loss (MAE): 0.0688
# 2025-07-29 19:53:09 [INFO]: Epoch 090 - training loss (MAE): 0.0697
# 2025-07-29 19:53:10 [INFO]: Epoch 091 - training loss (MAE): 0.0686
# 2025-07-29 19:53:11 [INFO]: Epoch 092 - training loss (MAE): 0.0689
# 2025-07-29 19:53:12 [INFO]: Epoch 093 - training loss (MAE): 0.0691
# 2025-07-29 19:53:13 [INFO]: Epoch 094 - training loss (MAE): 0.0684
# 2025-07-29 19:53:14 [INFO]: Epoch 095 - training loss (MAE): 0.0669
# 2025-07-29 19:53:15 [INFO]: Epoch 096 - training loss (MAE): 0.0662
# 2025-07-29 19:53:16 [INFO]: Epoch 097 - training loss (MAE): 0.0659
# 2025-07-29 19:53:17 [INFO]: Epoch 098 - training loss (MAE): 0.0664
# 2025-07-29 19:53:18 [INFO]: Epoch 099 - training loss (MAE): 0.0659
# 2025-07-29 19:53:19 [INFO]: Epoch 100 - training loss (MAE): 0.0664
# 2025-07-29 19:53:19 [INFO]: Epoch 101 - training loss (MAE): 0.0668
# 2025-07-29 19:53:20 [INFO]: Epoch 102 - training loss (MAE): 0.0654
# 2025-07-29 19:53:21 [INFO]: Epoch 103 - training loss (MAE): 0.0660
# 2025-07-29 19:53:22 [INFO]: Epoch 104 - training loss (MAE): 0.0654
# 2025-07-29 19:53:23 [INFO]: Epoch 105 - training loss (MAE): 0.0649
# 2025-07-29 19:53:24 [INFO]: Epoch 106 - training loss (MAE): 0.0645
# 2025-07-29 19:53:25 [INFO]: Epoch 107 - training loss (MAE): 0.0648
# 2025-07-29 19:53:26 [INFO]: Epoch 108 - training loss (MAE): 0.0642
# 2025-07-29 19:53:27 [INFO]: Epoch 109 - training loss (MAE): 0.0637
# 2025-07-29 19:53:28 [INFO]: Epoch 110 - training loss (MAE): 0.0640
# 2025-07-29 19:53:29 [INFO]: Epoch 111 - training loss (MAE): 0.0632
# 2025-07-29 19:53:30 [INFO]: Epoch 112 - training loss (MAE): 0.0632
# 2025-07-29 19:53:31 [INFO]: Epoch 113 - training loss (MAE): 0.0628
# 2025-07-29 19:53:32 [INFO]: Epoch 114 - training loss (MAE): 0.0627
# 2025-07-29 19:53:33 [INFO]: Epoch 115 - training loss (MAE): 0.0630
# 2025-07-29 19:53:34 [INFO]: Epoch 116 - training loss (MAE): 0.0625
# 2025-07-29 19:53:35 [INFO]: Epoch 117 - training loss (MAE): 0.0643
# 2025-07-29 19:53:36 [INFO]: Epoch 118 - training loss (MAE): 0.0648
# 2025-07-29 19:53:37 [INFO]: Epoch 119 - training loss (MAE): 0.0636
# 2025-07-29 19:53:38 [INFO]: Epoch 120 - training loss (MAE): 0.0623
# 2025-07-29 19:53:39 [INFO]: Epoch 121 - training loss (MAE): 0.0624
# 2025-07-29 19:53:40 [INFO]: Epoch 122 - training loss (MAE): 0.0631
# 2025-07-29 19:53:41 [INFO]: Epoch 123 - training loss (MAE): 0.0617
# 2025-07-29 19:53:42 [INFO]: Epoch 124 - training loss (MAE): 0.0608
# 2025-07-29 19:53:43 [INFO]: Epoch 125 - training loss (MAE): 0.0620
# 2025-07-29 19:53:44 [INFO]: Epoch 126 - training loss (MAE): 0.0622
# 2025-07-29 19:53:45 [INFO]: Epoch 127 - training loss (MAE): 0.0610
# 2025-07-29 19:53:46 [INFO]: Epoch 128 - training loss (MAE): 0.0614
# 2025-07-29 19:53:47 [INFO]: Epoch 129 - training loss (MAE): 0.0603
# 2025-07-29 19:53:48 [INFO]: Epoch 130 - training loss (MAE): 0.0601
# 2025-07-29 19:53:49 [INFO]: Epoch 131 - training loss (MAE): 0.0600
# 2025-07-29 19:53:49 [INFO]: Epoch 132 - training loss (MAE): 0.0577
# 2025-07-29 19:53:50 [INFO]: Epoch 133 - training loss (MAE): 0.0585
# 2025-07-29 19:53:51 [INFO]: Epoch 134 - training loss (MAE): 0.0576
# 2025-07-29 19:53:52 [INFO]: Epoch 135 - training loss (MAE): 0.0577
# 2025-07-29 19:53:53 [INFO]: Epoch 136 - training loss (MAE): 0.0568
# 2025-07-29 19:53:54 [INFO]: Epoch 137 - training loss (MAE): 0.0560
# 2025-07-29 19:53:55 [INFO]: Epoch 138 - training loss (MAE): 0.0566
# 2025-07-29 19:53:56 [INFO]: Epoch 139 - training loss (MAE): 0.0555
# 2025-07-29 19:53:57 [INFO]: Epoch 140 - training loss (MAE): 0.0548
# 2025-07-29 19:53:58 [INFO]: Epoch 141 - training loss (MAE): 0.0541
# 2025-07-29 19:53:59 [INFO]: Epoch 142 - training loss (MAE): 0.0535
# 2025-07-29 19:54:00 [INFO]: Epoch 143 - training loss (MAE): 0.0553
# 2025-07-29 19:54:01 [INFO]: Epoch 144 - training loss (MAE): 0.0546
# 2025-07-29 19:54:02 [INFO]: Epoch 145 - training loss (MAE): 0.0533
# 2025-07-29 19:54:03 [INFO]: Epoch 146 - training loss (MAE): 0.0527
# 2025-07-29 19:54:04 [INFO]: Epoch 147 - training loss (MAE): 0.0525
# 2025-07-29 19:54:05 [INFO]: Epoch 148 - training loss (MAE): 0.0539
# 2025-07-29 19:54:06 [INFO]: Epoch 149 - training loss (MAE): 0.0515
# 2025-07-29 19:54:07 [INFO]: Epoch 150 - training loss (MAE): 0.0521
# 2025-07-29 19:54:08 [INFO]: Epoch 151 - training loss (MAE): 0.0515
# 2025-07-29 19:54:09 [INFO]: Epoch 152 - training loss (MAE): 0.0519
# 2025-07-29 19:54:10 [INFO]: Epoch 153 - training loss (MAE): 0.0511
# 2025-07-29 19:54:11 [INFO]: Epoch 154 - training loss (MAE): 0.0501
# 2025-07-29 19:54:12 [INFO]: Epoch 155 - training loss (MAE): 0.0509
# 2025-07-29 19:54:13 [INFO]: Epoch 156 - training loss (MAE): 0.0504
# 2025-07-29 19:54:14 [INFO]: Epoch 157 - training loss (MAE): 0.0508
# 2025-07-29 19:54:15 [INFO]: Epoch 158 - training loss (MAE): 0.0500
# 2025-07-29 19:54:16 [INFO]: Epoch 159 - training loss (MAE): 0.0509
# 2025-07-29 19:54:17 [INFO]: Epoch 160 - training loss (MAE): 0.0511
# 2025-07-29 19:54:18 [INFO]: Epoch 161 - training loss (MAE): 0.0510
# 2025-07-29 19:54:19 [INFO]: Epoch 162 - training loss (MAE): 0.0501
# 2025-07-29 19:54:20 [INFO]: Epoch 163 - training loss (MAE): 0.0501
# 2025-07-29 19:54:20 [INFO]: Epoch 164 - training loss (MAE): 0.0495
# 2025-07-29 19:54:21 [INFO]: Epoch 165 - training loss (MAE): 0.0494
# 2025-07-29 19:54:22 [INFO]: Epoch 166 - training loss (MAE): 0.0500
# 2025-07-29 19:54:23 [INFO]: Epoch 167 - training loss (MAE): 0.0492
# 2025-07-29 19:54:24 [INFO]: Epoch 168 - training loss (MAE): 0.0495
# 2025-07-29 19:54:25 [INFO]: Epoch 169 - training loss (MAE): 0.0486
# 2025-07-29 19:54:26 [INFO]: Epoch 170 - training loss (MAE): 0.0484
# 2025-07-29 19:54:27 [INFO]: Epoch 171 - training loss (MAE): 0.0487
# 2025-07-29 19:54:28 [INFO]: Epoch 172 - training loss (MAE): 0.0497
# 2025-07-29 19:54:29 [INFO]: Epoch 173 - training loss (MAE): 0.0483
# 2025-07-29 19:54:30 [INFO]: Epoch 174 - training loss (MAE): 0.0478
# 2025-07-29 19:54:31 [INFO]: Epoch 175 - training loss (MAE): 0.0474
# 2025-07-29 19:54:32 [INFO]: Epoch 176 - training loss (MAE): 0.0477
# 2025-07-29 19:54:33 [INFO]: Epoch 177 - training loss (MAE): 0.0470
# 2025-07-29 19:54:34 [INFO]: Epoch 178 - training loss (MAE): 0.0475
# 2025-07-29 19:54:35 [INFO]: Epoch 179 - training loss (MAE): 0.0481
# 2025-07-29 19:54:36 [INFO]: Epoch 180 - training loss (MAE): 0.0476
# 2025-07-29 19:54:37 [INFO]: Epoch 181 - training loss (MAE): 0.0476
# 2025-07-29 19:54:38 [INFO]: Epoch 182 - training loss (MAE): 0.0479
# 2025-07-29 19:54:39 [INFO]: Epoch 183 - training loss (MAE): 0.0475
# 2025-07-29 19:54:40 [INFO]: Epoch 184 - training loss (MAE): 0.0470
# 2025-07-29 19:54:41 [INFO]: Epoch 185 - training loss (MAE): 0.0472
# 2025-07-29 19:54:42 [INFO]: Epoch 186 - training loss (MAE): 0.0464
# 2025-07-29 19:54:43 [INFO]: Epoch 187 - training loss (MAE): 0.0479
# 2025-07-29 19:54:44 [INFO]: Epoch 188 - training loss (MAE): 0.0468
# 2025-07-29 19:54:45 [INFO]: Epoch 189 - training loss (MAE): 0.0476
# 2025-07-29 19:54:46 [INFO]: Epoch 190 - training loss (MAE): 0.0466
# 2025-07-29 19:54:47 [INFO]: Epoch 191 - training loss (MAE): 0.0459
# 2025-07-29 19:54:48 [INFO]: Epoch 192 - training loss (MAE): 0.0467
# 2025-07-29 19:54:49 [INFO]: Epoch 193 - training loss (MAE): 0.0473
# 2025-07-29 19:54:50 [INFO]: Epoch 194 - training loss (MAE): 0.0461
# 2025-07-29 19:54:51 [INFO]: Epoch 195 - training loss (MAE): 0.0458
# 2025-07-29 19:54:52 [INFO]: Epoch 196 - training loss (MAE): 0.0464
# 2025-07-29 19:54:52 [INFO]: Epoch 197 - training loss (MAE): 0.0471
# 2025-07-29 19:54:53 [INFO]: Epoch 198 - training loss (MAE): 0.0470
# 2025-07-29 19:54:54 [INFO]: Epoch 199 - training loss (MAE): 0.0462
# 2025-07-29 19:54:55 [INFO]: Epoch 200 - training loss (MAE): 0.0462
# 2025-07-29 19:54:56 [INFO]: Epoch 201 - training loss (MAE): 0.0458
# 2025-07-29 19:54:57 [INFO]: Epoch 202 - training loss (MAE): 0.0461
# 2025-07-29 19:54:58 [INFO]: Epoch 203 - training loss (MAE): 0.0462
# 2025-07-29 19:54:59 [INFO]: Epoch 204 - training loss (MAE): 0.0456
# 2025-07-29 19:55:00 [INFO]: Epoch 205 - training loss (MAE): 0.0455
# 2025-07-29 19:55:01 [INFO]: Epoch 206 - training loss (MAE): 0.0456
# 2025-07-29 19:55:02 [INFO]: Epoch 207 - training loss (MAE): 0.0459
# 2025-07-29 19:55:03 [INFO]: Epoch 208 - training loss (MAE): 0.0461
# 2025-07-29 19:55:04 [INFO]: Epoch 209 - training loss (MAE): 0.0452
# 2025-07-29 19:55:05 [INFO]: Epoch 210 - training loss (MAE): 0.0458
# 2025-07-29 19:55:06 [INFO]: Epoch 211 - training loss (MAE): 0.0463
# 2025-07-29 19:55:07 [INFO]: Epoch 212 - training loss (MAE): 0.0467
# 2025-07-29 19:55:08 [INFO]: Epoch 213 - training loss (MAE): 0.0469
# 2025-07-29 19:55:09 [INFO]: Epoch 214 - training loss (MAE): 0.0456
# 2025-07-29 19:55:10 [INFO]: Epoch 215 - training loss (MAE): 0.0447
# 2025-07-29 19:55:11 [INFO]: Epoch 216 - training loss (MAE): 0.0451
# 2025-07-29 19:55:12 [INFO]: Epoch 217 - training loss (MAE): 0.0440
# 2025-07-29 19:55:13 [INFO]: Epoch 218 - training loss (MAE): 0.0446
# 2025-07-29 19:55:14 [INFO]: Epoch 219 - training loss (MAE): 0.0442
# 2025-07-29 19:55:15 [INFO]: Epoch 220 - training loss (MAE): 0.0442
# 2025-07-29 19:55:16 [INFO]: Epoch 221 - training loss (MAE): 0.0425
# 2025-07-29 19:55:17 [INFO]: Epoch 222 - training loss (MAE): 0.0430
# 2025-07-29 19:55:18 [INFO]: Epoch 223 - training loss (MAE): 0.0414
# 2025-07-29 19:55:19 [INFO]: Epoch 224 - training loss (MAE): 0.0411
# 2025-07-29 19:55:20 [INFO]: Epoch 225 - training loss (MAE): 0.0413
# 2025-07-29 19:55:21 [INFO]: Epoch 226 - training loss (MAE): 0.0409
# 2025-07-29 19:55:22 [INFO]: Epoch 227 - training loss (MAE): 0.0405
# 2025-07-29 19:55:23 [INFO]: Epoch 228 - training loss (MAE): 0.0398
# 2025-07-29 19:55:24 [INFO]: Epoch 229 - training loss (MAE): 0.0399
# 2025-07-29 19:55:25 [INFO]: Epoch 230 - training loss (MAE): 0.0397
# 2025-07-29 19:55:26 [INFO]: Epoch 231 - training loss (MAE): 0.0402
# 2025-07-29 19:55:27 [INFO]: Epoch 232 - training loss (MAE): 0.0405
# 2025-07-29 19:55:28 [INFO]: Epoch 233 - training loss (MAE): 0.0406
# 2025-07-29 19:55:29 [INFO]: Epoch 234 - training loss (MAE): 0.0394
# 2025-07-29 19:55:30 [INFO]: Epoch 235 - training loss (MAE): 0.0400
# 2025-07-29 19:55:31 [INFO]: Epoch 236 - training loss (MAE): 0.0394
# 2025-07-29 19:55:31 [INFO]: Epoch 237 - training loss (MAE): 0.0405
# 2025-07-29 19:55:32 [INFO]: Epoch 238 - training loss (MAE): 0.0397
# 2025-07-29 19:55:33 [INFO]: Epoch 239 - training loss (MAE): 0.0398
# 2025-07-29 19:55:34 [INFO]: Epoch 240 - training loss (MAE): 0.0390
# 2025-07-29 19:55:35 [INFO]: Epoch 241 - training loss (MAE): 0.0398
# 2025-07-29 19:55:36 [INFO]: Epoch 242 - training loss (MAE): 0.0398
# 2025-07-29 19:55:37 [INFO]: Epoch 243 - training loss (MAE): 0.0390
# 2025-07-29 19:55:38 [INFO]: Epoch 244 - training loss (MAE): 0.0390
# 2025-07-29 19:55:39 [INFO]: Epoch 245 - training loss (MAE): 0.0388
# 2025-07-29 19:55:40 [INFO]: Epoch 246 - training loss (MAE): 0.0392
# 2025-07-29 19:55:41 [INFO]: Epoch 247 - training loss (MAE): 0.0383
# 2025-07-29 19:55:42 [INFO]: Epoch 248 - training loss (MAE): 0.0389
# 2025-07-29 19:55:43 [INFO]: Epoch 249 - training loss (MAE): 0.0383
# 2025-07-29 19:55:44 [INFO]: Epoch 250 - training loss (MAE): 0.0385
# 2025-07-29 19:55:45 [INFO]: Epoch 251 - training loss (MAE): 0.0384
# 2025-07-29 19:55:46 [INFO]: Epoch 252 - training loss (MAE): 0.0381
# 2025-07-29 19:55:47 [INFO]: Epoch 253 - training loss (MAE): 0.0380
# 2025-07-29 19:55:48 [INFO]: Epoch 254 - training loss (MAE): 0.0388
# 2025-07-29 19:55:49 [INFO]: Epoch 255 - training loss (MAE): 0.0384
# 2025-07-29 19:55:50 [INFO]: Epoch 256 - training loss (MAE): 0.0375
# 2025-07-29 19:55:51 [INFO]: Epoch 257 - training loss (MAE): 0.0377
# 2025-07-29 19:55:52 [INFO]: Epoch 258 - training loss (MAE): 0.0384
# 2025-07-29 19:55:53 [INFO]: Epoch 259 - training loss (MAE): 0.0376
# 2025-07-29 19:55:54 [INFO]: Epoch 260 - training loss (MAE): 0.0371
# 2025-07-29 19:55:55 [INFO]: Epoch 261 - training loss (MAE): 0.0372
# 2025-07-29 19:55:56 [INFO]: Epoch 262 - training loss (MAE): 0.0376
# 2025-07-29 19:55:57 [INFO]: Epoch 263 - training loss (MAE): 0.0379
# 2025-07-29 19:55:58 [INFO]: Epoch 264 - training loss (MAE): 0.0374
# 2025-07-29 19:55:59 [INFO]: Epoch 265 - training loss (MAE): 0.0366
# 2025-07-29 19:56:00 [INFO]: Epoch 266 - training loss (MAE): 0.0369
# 2025-07-29 19:56:01 [INFO]: Epoch 267 - training loss (MAE): 0.0367
# 2025-07-29 19:56:02 [INFO]: Epoch 268 - training loss (MAE): 0.0366
# 2025-07-29 19:56:03 [INFO]: Epoch 269 - training loss (MAE): 0.0367
# 2025-07-29 19:56:04 [INFO]: Epoch 270 - training loss (MAE): 0.0372
# 2025-07-29 19:56:05 [INFO]: Epoch 271 - training loss (MAE): 0.0371
# 2025-07-29 19:56:06 [INFO]: Epoch 272 - training loss (MAE): 0.0366
# 2025-07-29 19:56:07 [INFO]: Epoch 273 - training loss (MAE): 0.0367
# 2025-07-29 19:56:08 [INFO]: Epoch 274 - training loss (MAE): 0.0367
# 2025-07-29 19:56:09 [INFO]: Epoch 275 - training loss (MAE): 0.0370
# 2025-07-29 19:56:10 [INFO]: Epoch 276 - training loss (MAE): 0.0363
# 2025-07-29 19:56:10 [INFO]: Epoch 277 - training loss (MAE): 0.0367
# 2025-07-29 19:56:11 [INFO]: Epoch 278 - training loss (MAE): 0.0363
# 2025-07-29 19:56:12 [INFO]: Epoch 279 - training loss (MAE): 0.0359
# 2025-07-29 19:56:13 [INFO]: Epoch 280 - training loss (MAE): 0.0370
# 2025-07-29 19:56:14 [INFO]: Epoch 281 - training loss (MAE): 0.0373
# 2025-07-29 19:56:15 [INFO]: Epoch 282 - training loss (MAE): 0.0361
# 2025-07-29 19:56:16 [INFO]: Epoch 283 - training loss (MAE): 0.0355
# 2025-07-29 19:56:17 [INFO]: Epoch 284 - training loss (MAE): 0.0371
# 2025-07-29 19:56:18 [INFO]: Epoch 285 - training loss (MAE): 0.0366
# 2025-07-29 19:56:19 [INFO]: Epoch 286 - training loss (MAE): 0.0370
# 2025-07-29 19:56:20 [INFO]: Epoch 287 - training loss (MAE): 0.0362
# 2025-07-29 19:56:21 [INFO]: Epoch 288 - training loss (MAE): 0.0371
# 2025-07-29 19:56:22 [INFO]: Epoch 289 - training loss (MAE): 0.0364
# 2025-07-29 19:56:23 [INFO]: Epoch 290 - training loss (MAE): 0.0357
# 2025-07-29 19:56:24 [INFO]: Epoch 291 - training loss (MAE): 0.0357
# 2025-07-29 19:56:25 [INFO]: Epoch 292 - training loss (MAE): 0.0361
# 2025-07-29 19:56:26 [INFO]: Epoch 293 - training loss (MAE): 0.0360
# 2025-07-29 19:56:27 [INFO]: Epoch 294 - training loss (MAE): 0.0356
# 2025-07-29 19:56:28 [INFO]: Epoch 295 - training loss (MAE): 0.0356
# 2025-07-29 19:56:29 [INFO]: Epoch 296 - training loss (MAE): 0.0360
# 2025-07-29 19:56:30 [INFO]: Epoch 297 - training loss (MAE): 0.0355
# 2025-07-29 19:56:31 [INFO]: Epoch 298 - training loss (MAE): 0.0360
# 2025-07-29 19:56:32 [INFO]: Epoch 299 - training loss (MAE): 0.0355
# 2025-07-29 19:56:33 [INFO]: Epoch 300 - training loss (MAE): 0.0357
# 2025-07-29 19:56:34 [INFO]: Epoch 301 - training loss (MAE): 0.0361
# 2025-07-29 19:56:35 [INFO]: Epoch 302 - training loss (MAE): 0.0354
# 2025-07-29 19:56:36 [INFO]: Epoch 303 - training loss (MAE): 0.0353
# 2025-07-29 19:56:37 [INFO]: Epoch 304 - training loss (MAE): 0.0358
# 2025-07-29 19:56:38 [INFO]: Epoch 305 - training loss (MAE): 0.0357
# 2025-07-29 19:56:39 [INFO]: Epoch 306 - training loss (MAE): 0.0365
# 2025-07-29 19:56:40 [INFO]: Epoch 307 - training loss (MAE): 0.0354
# 2025-07-29 19:56:41 [INFO]: Epoch 308 - training loss (MAE): 0.0351
# 2025-07-29 19:56:42 [INFO]: Epoch 309 - training loss (MAE): 0.0354
# 2025-07-29 19:56:43 [INFO]: Epoch 310 - training loss (MAE): 0.0352
# 2025-07-29 19:56:44 [INFO]: Epoch 311 - training loss (MAE): 0.0348
# 2025-07-29 19:56:45 [INFO]: Epoch 312 - training loss (MAE): 0.0344
# 2025-07-29 19:56:46 [INFO]: Epoch 313 - training loss (MAE): 0.0357
# 2025-07-29 19:56:47 [INFO]: Epoch 314 - training loss (MAE): 0.0362
# 2025-07-29 19:56:48 [INFO]: Epoch 315 - training loss (MAE): 0.0353
# 2025-07-29 19:56:49 [INFO]: Epoch 316 - training loss (MAE): 0.0354
# 2025-07-29 19:56:50 [INFO]: Epoch 317 - training loss (MAE): 0.0351
# 2025-07-29 19:56:51 [INFO]: Epoch 318 - training loss (MAE): 0.0348
# 2025-07-29 19:56:52 [INFO]: Epoch 319 - training loss (MAE): 0.0346
# 2025-07-29 19:56:53 [INFO]: Epoch 320 - training loss (MAE): 0.0350
# 2025-07-29 19:56:54 [INFO]: Epoch 321 - training loss (MAE): 0.0349
# 2025-07-29 19:56:55 [INFO]: Epoch 322 - training loss (MAE): 0.0347
# 2025-07-29 19:56:56 [INFO]: Epoch 323 - training loss (MAE): 0.0349
# 2025-07-29 19:56:57 [INFO]: Epoch 324 - training loss (MAE): 0.0351
# 2025-07-29 19:56:57 [INFO]: Epoch 325 - training loss (MAE): 0.0352
# 2025-07-29 19:56:58 [INFO]: Epoch 326 - training loss (MAE): 0.0347
# 2025-07-29 19:56:59 [INFO]: Epoch 327 - training loss (MAE): 0.0347
# 2025-07-29 19:57:00 [INFO]: Epoch 328 - training loss (MAE): 0.0344
# 2025-07-29 19:57:01 [INFO]: Epoch 329 - training loss (MAE): 0.0343
# 2025-07-29 19:57:02 [INFO]: Epoch 330 - training loss (MAE): 0.0345
# 2025-07-29 19:57:03 [INFO]: Epoch 331 - training loss (MAE): 0.0347
# 2025-07-29 19:57:04 [INFO]: Epoch 332 - training loss (MAE): 0.0348
# 2025-07-29 19:57:05 [INFO]: Epoch 333 - training loss (MAE): 0.0349
# 2025-07-29 19:57:06 [INFO]: Epoch 334 - training loss (MAE): 0.0350
# 2025-07-29 19:57:07 [INFO]: Epoch 335 - training loss (MAE): 0.0342
# 2025-07-29 19:57:08 [INFO]: Epoch 336 - training loss (MAE): 0.0343
# 2025-07-29 19:57:09 [INFO]: Epoch 337 - training loss (MAE): 0.0343
# 2025-07-29 19:57:10 [INFO]: Epoch 338 - training loss (MAE): 0.0338
# 2025-07-29 19:57:11 [INFO]: Epoch 339 - training loss (MAE): 0.0347
# 2025-07-29 19:57:12 [INFO]: Epoch 340 - training loss (MAE): 0.0352
# 2025-07-29 19:57:13 [INFO]: Epoch 341 - training loss (MAE): 0.0354
# 2025-07-29 19:57:14 [INFO]: Epoch 342 - training loss (MAE): 0.0354
# 2025-07-29 19:57:15 [INFO]: Epoch 343 - training loss (MAE): 0.0347
# 2025-07-29 19:57:16 [INFO]: Epoch 344 - training loss (MAE): 0.0340
# 2025-07-29 19:57:17 [INFO]: Epoch 345 - training loss (MAE): 0.0340
# 2025-07-29 19:57:18 [INFO]: Epoch 346 - training loss (MAE): 0.0344
# 2025-07-29 19:57:19 [INFO]: Epoch 347 - training loss (MAE): 0.0344
# 2025-07-29 19:57:20 [INFO]: Epoch 348 - training loss (MAE): 0.0340
# 2025-07-29 19:57:21 [INFO]: Epoch 349 - training loss (MAE): 0.0334
# 2025-07-29 19:57:22 [INFO]: Epoch 350 - training loss (MAE): 0.0335
# 2025-07-29 19:57:23 [INFO]: Epoch 351 - training loss (MAE): 0.0336
# 2025-07-29 19:57:24 [INFO]: Epoch 352 - training loss (MAE): 0.0342
# 2025-07-29 19:57:25 [INFO]: Epoch 353 - training loss (MAE): 0.0341
# 2025-07-29 19:57:26 [INFO]: Epoch 354 - training loss (MAE): 0.0341
# 2025-07-29 19:57:27 [INFO]: Epoch 355 - training loss (MAE): 0.0334
# 2025-07-29 19:57:28 [INFO]: Epoch 356 - training loss (MAE): 0.0337
# 2025-07-29 19:57:29 [INFO]: Epoch 357 - training loss (MAE): 0.0341
# 2025-07-29 19:57:30 [INFO]: Epoch 358 - training loss (MAE): 0.0336
# 2025-07-29 19:57:31 [INFO]: Epoch 359 - training loss (MAE): 0.0335
# 2025-07-29 19:57:32 [INFO]: Epoch 360 - training loss (MAE): 0.0330
# 2025-07-29 19:57:33 [INFO]: Epoch 361 - training loss (MAE): 0.0331
# 2025-07-29 19:57:34 [INFO]: Epoch 362 - training loss (MAE): 0.0335
# 2025-07-29 19:57:35 [INFO]: Epoch 363 - training loss (MAE): 0.0341
# 2025-07-29 19:57:36 [INFO]: Epoch 364 - training loss (MAE): 0.0359
# 2025-07-29 19:57:37 [INFO]: Epoch 365 - training loss (MAE): 0.0352
# 2025-07-29 19:57:38 [INFO]: Epoch 366 - training loss (MAE): 0.0338
# 2025-07-29 19:57:39 [INFO]: Epoch 367 - training loss (MAE): 0.0336
# 2025-07-29 19:57:40 [INFO]: Epoch 368 - training loss (MAE): 0.0337
# 2025-07-29 19:57:41 [INFO]: Epoch 369 - training loss (MAE): 0.0333
# 2025-07-29 19:57:41 [INFO]: Epoch 370 - training loss (MAE): 0.0336
# 2025-07-29 19:57:42 [INFO]: Epoch 371 - training loss (MAE): 0.0329
# 2025-07-29 19:57:43 [INFO]: Epoch 372 - training loss (MAE): 0.0327
# 2025-07-29 19:57:44 [INFO]: Epoch 373 - training loss (MAE): 0.0334
# 2025-07-29 19:57:45 [INFO]: Epoch 374 - training loss (MAE): 0.0332
# 2025-07-29 19:57:46 [INFO]: Epoch 375 - training loss (MAE): 0.0331
# 2025-07-29 19:57:47 [INFO]: Epoch 376 - training loss (MAE): 0.0329
# 2025-07-29 19:57:48 [INFO]: Epoch 377 - training loss (MAE): 0.0337
# 2025-07-29 19:57:49 [INFO]: Epoch 378 - training loss (MAE): 0.0334
# 2025-07-29 19:57:50 [INFO]: Epoch 379 - training loss (MAE): 0.0333
# 2025-07-29 19:57:51 [INFO]: Epoch 380 - training loss (MAE): 0.0331
# 2025-07-29 19:57:52 [INFO]: Epoch 381 - training loss (MAE): 0.0330
# 2025-07-29 19:57:53 [INFO]: Epoch 382 - training loss (MAE): 0.0327
# 2025-07-29 19:57:54 [INFO]: Epoch 383 - training loss (MAE): 0.0329
# 2025-07-29 19:57:55 [INFO]: Epoch 384 - training loss (MAE): 0.0335
# 2025-07-29 19:57:56 [INFO]: Epoch 385 - training loss (MAE): 0.0335
# 2025-07-29 19:57:57 [INFO]: Epoch 386 - training loss (MAE): 0.0338
# 2025-07-29 19:57:58 [INFO]: Epoch 387 - training loss (MAE): 0.0333
# 2025-07-29 19:57:59 [INFO]: Epoch 388 - training loss (MAE): 0.0328
# 2025-07-29 19:58:00 [INFO]: Epoch 389 - training loss (MAE): 0.0328
# 2025-07-29 19:58:01 [INFO]: Epoch 390 - training loss (MAE): 0.0329
# 2025-07-29 19:58:02 [INFO]: Epoch 391 - training loss (MAE): 0.0331
# 2025-07-29 19:58:03 [INFO]: Epoch 392 - training loss (MAE): 0.0330
# 2025-07-29 19:58:04 [INFO]: Epoch 393 - training loss (MAE): 0.0325
# 2025-07-29 19:58:05 [INFO]: Epoch 394 - training loss (MAE): 0.0322
# 2025-07-29 19:58:06 [INFO]: Epoch 395 - training loss (MAE): 0.0328
# 2025-07-29 19:58:07 [INFO]: Epoch 396 - training loss (MAE): 0.0330
# 2025-07-29 19:58:08 [INFO]: Epoch 397 - training loss (MAE): 0.0330
# 2025-07-29 19:58:09 [INFO]: Epoch 398 - training loss (MAE): 0.0333
# 2025-07-29 19:58:10 [INFO]: Epoch 399 - training loss (MAE): 0.0329
# 2025-07-29 19:58:11 [INFO]: Epoch 400 - training loss (MAE): 0.0335
# 2025-07-29 19:58:12 [INFO]: Epoch 401 - training loss (MAE): 0.0348
# 2025-07-29 19:58:13 [INFO]: Epoch 402 - training loss (MAE): 0.0330
# 2025-07-29 19:58:14 [INFO]: Epoch 403 - training loss (MAE): 0.0336
# 2025-07-29 19:58:14 [INFO]: Epoch 404 - training loss (MAE): 0.0339
# 2025-07-29 19:58:15 [INFO]: Epoch 405 - training loss (MAE): 0.0339
# 2025-07-29 19:58:16 [INFO]: Epoch 406 - training loss (MAE): 0.0341
# 2025-07-29 19:58:17 [INFO]: Epoch 407 - training loss (MAE): 0.0336
# 2025-07-29 19:58:18 [INFO]: Epoch 408 - training loss (MAE): 0.0340
# 2025-07-29 19:58:19 [INFO]: Epoch 409 - training loss (MAE): 0.0339
# 2025-07-29 19:58:20 [INFO]: Epoch 410 - training loss (MAE): 0.0329
# 2025-07-29 19:58:21 [INFO]: Epoch 411 - training loss (MAE): 0.0325
# 2025-07-29 19:58:22 [INFO]: Epoch 412 - training loss (MAE): 0.0333
# 2025-07-29 19:58:23 [INFO]: Epoch 413 - training loss (MAE): 0.0335
# 2025-07-29 19:58:24 [INFO]: Epoch 414 - training loss (MAE): 0.0328
# 2025-07-29 19:58:25 [INFO]: Epoch 415 - training loss (MAE): 0.0327
# 2025-07-29 19:58:26 [INFO]: Epoch 416 - training loss (MAE): 0.0323
# 2025-07-29 19:58:27 [INFO]: Epoch 417 - training loss (MAE): 0.0332
# 2025-07-29 19:58:28 [INFO]: Epoch 418 - training loss (MAE): 0.0327
# 2025-07-29 19:58:29 [INFO]: Epoch 419 - training loss (MAE): 0.0332
# 2025-07-29 19:58:30 [INFO]: Epoch 420 - training loss (MAE): 0.0329
# 2025-07-29 19:58:31 [INFO]: Epoch 421 - training loss (MAE): 0.0319
# 2025-07-29 19:58:32 [INFO]: Epoch 422 - training loss (MAE): 0.0319
# 2025-07-29 19:58:33 [INFO]: Epoch 423 - training loss (MAE): 0.0324
# 2025-07-29 19:58:34 [INFO]: Epoch 424 - training loss (MAE): 0.0328
# 2025-07-29 19:58:35 [INFO]: Epoch 425 - training loss (MAE): 0.0325
# 2025-07-29 19:58:36 [INFO]: Epoch 426 - training loss (MAE): 0.0321
# 2025-07-29 19:58:37 [INFO]: Epoch 427 - training loss (MAE): 0.0322
# 2025-07-29 19:58:38 [INFO]: Epoch 428 - training loss (MAE): 0.0321
# 2025-07-29 19:58:39 [INFO]: Epoch 429 - training loss (MAE): 0.0317
# 2025-07-29 19:58:40 [INFO]: Epoch 430 - training loss (MAE): 0.0322
# 2025-07-29 19:58:41 [INFO]: Epoch 431 - training loss (MAE): 0.0314
# 2025-07-29 19:58:42 [INFO]: Epoch 432 - training loss (MAE): 0.0313
# 2025-07-29 19:58:43 [INFO]: Epoch 433 - training loss (MAE): 0.0314
# 2025-07-29 19:58:44 [INFO]: Epoch 434 - training loss (MAE): 0.0315
# 2025-07-29 19:58:45 [INFO]: Epoch 435 - training loss (MAE): 0.0317
# 2025-07-29 19:58:46 [INFO]: Epoch 436 - training loss (MAE): 0.0328
# 2025-07-29 19:58:47 [INFO]: Epoch 437 - training loss (MAE): 0.0323
# 2025-07-29 19:58:48 [INFO]: Epoch 438 - training loss (MAE): 0.0323
# 2025-07-29 19:58:49 [INFO]: Epoch 439 - training loss (MAE): 0.0323
# 2025-07-29 19:58:50 [INFO]: Epoch 440 - training loss (MAE): 0.0324
# 2025-07-29 19:58:51 [INFO]: Epoch 441 - training loss (MAE): 0.0318
# 2025-07-29 19:58:52 [INFO]: Epoch 442 - training loss (MAE): 0.0319
# 2025-07-29 19:58:53 [INFO]: Epoch 443 - training loss (MAE): 0.0334
# 2025-07-29 19:58:54 [INFO]: Epoch 444 - training loss (MAE): 0.0332
# 2025-07-29 19:58:55 [INFO]: Epoch 445 - training loss (MAE): 0.0318
# 2025-07-29 19:58:56 [INFO]: Epoch 446 - training loss (MAE): 0.0322
# 2025-07-29 19:58:57 [INFO]: Epoch 447 - training loss (MAE): 0.0312
# 2025-07-29 19:58:58 [INFO]: Epoch 448 - training loss (MAE): 0.0301
# 2025-07-29 19:58:59 [INFO]: Epoch 449 - training loss (MAE): 0.0294
# 2025-07-29 19:59:00 [INFO]: Epoch 450 - training loss (MAE): 0.0292
# 2025-07-29 19:59:00 [INFO]: Epoch 451 - training loss (MAE): 0.0302
# 2025-07-29 19:59:01 [INFO]: Epoch 452 - training loss (MAE): 0.0307
# 2025-07-29 19:59:02 [INFO]: Epoch 453 - training loss (MAE): 0.0300
# 2025-07-29 19:59:03 [INFO]: Epoch 454 - training loss (MAE): 0.0294
# 2025-07-29 19:59:04 [INFO]: Epoch 455 - training loss (MAE): 0.0291
# 2025-07-29 19:59:05 [INFO]: Epoch 456 - training loss (MAE): 0.0296
# 2025-07-29 19:59:06 [INFO]: Epoch 457 - training loss (MAE): 0.0297
# 2025-07-29 19:59:07 [INFO]: Epoch 458 - training loss (MAE): 0.0288
# 2025-07-29 19:59:08 [INFO]: Epoch 459 - training loss (MAE): 0.0288
# 2025-07-29 19:59:09 [INFO]: Epoch 460 - training loss (MAE): 0.0288
# 2025-07-29 19:59:10 [INFO]: Epoch 461 - training loss (MAE): 0.0291
# 2025-07-29 19:59:11 [INFO]: Epoch 462 - training loss (MAE): 0.0290
# 2025-07-29 19:59:12 [INFO]: Epoch 463 - training loss (MAE): 0.0294
# 2025-07-29 19:59:13 [INFO]: Epoch 464 - training loss (MAE): 0.0286
# 2025-07-29 19:59:14 [INFO]: Epoch 465 - training loss (MAE): 0.0288
# 2025-07-29 19:59:15 [INFO]: Epoch 466 - training loss (MAE): 0.0284
# 2025-07-29 19:59:16 [INFO]: Epoch 467 - training loss (MAE): 0.0290
# 2025-07-29 19:59:17 [INFO]: Epoch 468 - training loss (MAE): 0.0296
# 2025-07-29 19:59:18 [INFO]: Epoch 469 - training loss (MAE): 0.0287
# 2025-07-29 19:59:19 [INFO]: Epoch 470 - training loss (MAE): 0.0288
# 2025-07-29 19:59:20 [INFO]: Epoch 471 - training loss (MAE): 0.0286
# 2025-07-29 19:59:21 [INFO]: Epoch 472 - training loss (MAE): 0.0286
# 2025-07-29 19:59:22 [INFO]: Epoch 473 - training loss (MAE): 0.0286
# 2025-07-29 19:59:23 [INFO]: Epoch 474 - training loss (MAE): 0.0276
# 2025-07-29 19:59:24 [INFO]: Epoch 475 - training loss (MAE): 0.0275
# 2025-07-29 19:59:25 [INFO]: Epoch 476 - training loss (MAE): 0.0287
# 2025-07-29 19:59:26 [INFO]: Epoch 477 - training loss (MAE): 0.0293
# 2025-07-29 19:59:27 [INFO]: Epoch 478 - training loss (MAE): 0.0290
# 2025-07-29 19:59:28 [INFO]: Epoch 479 - training loss (MAE): 0.0284
# 2025-07-29 19:59:29 [INFO]: Epoch 480 - training loss (MAE): 0.0275
# 2025-07-29 19:59:30 [INFO]: Epoch 481 - training loss (MAE): 0.0276
# 2025-07-29 19:59:31 [INFO]: Epoch 482 - training loss (MAE): 0.0285
# 2025-07-29 19:59:32 [INFO]: Epoch 483 - training loss (MAE): 0.0280
# 2025-07-29 19:59:33 [INFO]: Epoch 484 - training loss (MAE): 0.0299
# 2025-07-29 19:59:34 [INFO]: Epoch 485 - training loss (MAE): 0.0282
# 2025-07-29 19:59:35 [INFO]: Epoch 486 - training loss (MAE): 0.0277
# 2025-07-29 19:59:36 [INFO]: Epoch 487 - training loss (MAE): 0.0272
# 2025-07-29 19:59:37 [INFO]: Epoch 488 - training loss (MAE): 0.0281
# 2025-07-29 19:59:38 [INFO]: Epoch 489 - training loss (MAE): 0.0275
# 2025-07-29 19:59:38 [INFO]: Epoch 490 - training loss (MAE): 0.0269
# 2025-07-29 19:59:39 [INFO]: Epoch 491 - training loss (MAE): 0.0266
# 2025-07-29 19:59:40 [INFO]: Epoch 492 - training loss (MAE): 0.0276
# 2025-07-29 19:59:41 [INFO]: Epoch 493 - training loss (MAE): 0.0278
# 2025-07-29 19:59:42 [INFO]: Epoch 494 - training loss (MAE): 0.0273
# 2025-07-29 19:59:43 [INFO]: Epoch 495 - training loss (MAE): 0.0272
# 2025-07-29 19:59:44 [INFO]: Epoch 496 - training loss (MAE): 0.0277
# 2025-07-29 19:59:45 [INFO]: Epoch 497 - training loss (MAE): 0.0272
# 2025-07-29 19:59:46 [INFO]: Epoch 498 - training loss (MAE): 0.0270
# 2025-07-29 19:59:47 [INFO]: Epoch 499 - training loss (MAE): 0.0268
# 2025-07-29 19:59:48 [INFO]: Epoch 500 - training loss (MAE): 0.0273
# 2025-07-29 19:59:49 [INFO]: Epoch 501 - training loss (MAE): 0.0267
# 2025-07-29 19:59:50 [INFO]: Epoch 502 - training loss (MAE): 0.0277
# 2025-07-29 19:59:51 [INFO]: Epoch 503 - training loss (MAE): 0.0280
# 2025-07-29 19:59:52 [INFO]: Epoch 504 - training loss (MAE): 0.0269
# 2025-07-29 19:59:53 [INFO]: Epoch 505 - training loss (MAE): 0.0267
# 2025-07-29 19:59:54 [INFO]: Epoch 506 - training loss (MAE): 0.0268
# 2025-07-29 19:59:55 [INFO]: Epoch 507 - training loss (MAE): 0.0275
# 2025-07-29 19:59:56 [INFO]: Epoch 508 - training loss (MAE): 0.0274
# 2025-07-29 19:59:57 [INFO]: Epoch 509 - training loss (MAE): 0.0269
# 2025-07-29 19:59:58 [INFO]: Epoch 510 - training loss (MAE): 0.0274
# 2025-07-29 19:59:59 [INFO]: Epoch 511 - training loss (MAE): 0.0269
# 2025-07-29 20:00:00 [INFO]: Epoch 512 - training loss (MAE): 0.0268
# 2025-07-29 20:00:01 [INFO]: Epoch 513 - training loss (MAE): 0.0275
# 2025-07-29 20:00:02 [INFO]: Epoch 514 - training loss (MAE): 0.0269
# 2025-07-29 20:00:03 [INFO]: Epoch 515 - training loss (MAE): 0.0272
# 2025-07-29 20:00:04 [INFO]: Epoch 516 - training loss (MAE): 0.0274
# 2025-07-29 20:00:05 [INFO]: Epoch 517 - training loss (MAE): 0.0268
# 2025-07-29 20:00:06 [INFO]: Epoch 518 - training loss (MAE): 0.0267
# 2025-07-29 20:00:07 [INFO]: Epoch 519 - training loss (MAE): 0.0267
# 2025-07-29 20:00:08 [INFO]: Epoch 520 - training loss (MAE): 0.0271
# 2025-07-29 20:00:09 [INFO]: Epoch 521 - training loss (MAE): 0.0270
# 2025-07-29 20:00:10 [INFO]: Epoch 522 - training loss (MAE): 0.0272
# 2025-07-29 20:00:11 [INFO]: Epoch 523 - training loss (MAE): 0.0273
# 2025-07-29 20:00:12 [INFO]: Epoch 524 - training loss (MAE): 0.0271
# 2025-07-29 20:00:13 [INFO]: Epoch 525 - training loss (MAE): 0.0267
# 2025-07-29 20:00:14 [INFO]: Epoch 526 - training loss (MAE): 0.0267
# 2025-07-29 20:00:15 [INFO]: Epoch 527 - training loss (MAE): 0.0269
# 2025-07-29 20:00:16 [INFO]: Epoch 528 - training loss (MAE): 0.0265
# 2025-07-29 20:00:17 [INFO]: Epoch 529 - training loss (MAE): 0.0269
# 2025-07-29 20:00:18 [INFO]: Epoch 530 - training loss (MAE): 0.0270
# 2025-07-29 20:00:18 [INFO]: Epoch 531 - training loss (MAE): 0.0271
# 2025-07-29 20:00:19 [INFO]: Epoch 532 - training loss (MAE): 0.0272
# 2025-07-29 20:00:20 [INFO]: Epoch 533 - training loss (MAE): 0.0267
# 2025-07-29 20:00:21 [INFO]: Epoch 534 - training loss (MAE): 0.0260
# 2025-07-29 20:00:22 [INFO]: Epoch 535 - training loss (MAE): 0.0264
# 2025-07-29 20:00:23 [INFO]: Epoch 536 - training loss (MAE): 0.0256
# 2025-07-29 20:00:24 [INFO]: Epoch 537 - training loss (MAE): 0.0263
# 2025-07-29 20:00:25 [INFO]: Epoch 538 - training loss (MAE): 0.0262
# 2025-07-29 20:00:26 [INFO]: Epoch 539 - training loss (MAE): 0.0268
# 2025-07-29 20:00:27 [INFO]: Epoch 540 - training loss (MAE): 0.0271
# 2025-07-29 20:00:28 [INFO]: Epoch 541 - training loss (MAE): 0.0267
# 2025-07-29 20:00:29 [INFO]: Epoch 542 - training loss (MAE): 0.0262
# 2025-07-29 20:00:30 [INFO]: Epoch 543 - training loss (MAE): 0.0264
# 2025-07-29 20:00:31 [INFO]: Epoch 544 - training loss (MAE): 0.0263
# 2025-07-29 20:00:32 [INFO]: Epoch 545 - training loss (MAE): 0.0267
# 2025-07-29 20:00:33 [INFO]: Epoch 546 - training loss (MAE): 0.0261
# 2025-07-29 20:00:34 [INFO]: Epoch 547 - training loss (MAE): 0.0262
# 2025-07-29 20:00:35 [INFO]: Epoch 548 - training loss (MAE): 0.0280
# 2025-07-29 20:00:36 [INFO]: Epoch 549 - training loss (MAE): 0.0264
# 2025-07-29 20:00:37 [INFO]: Epoch 550 - training loss (MAE): 0.0269
# 2025-07-29 20:00:38 [INFO]: Epoch 551 - training loss (MAE): 0.0258
# 2025-07-29 20:00:39 [INFO]: Epoch 552 - training loss (MAE): 0.0261
# 2025-07-29 20:00:40 [INFO]: Epoch 553 - training loss (MAE): 0.0257
# 2025-07-29 20:00:41 [INFO]: Epoch 554 - training loss (MAE): 0.0257
# 2025-07-29 20:00:42 [INFO]: Epoch 555 - training loss (MAE): 0.0258
# 2025-07-29 20:00:43 [INFO]: Epoch 556 - training loss (MAE): 0.0256
# 2025-07-29 20:00:44 [INFO]: Epoch 557 - training loss (MAE): 0.0255
# 2025-07-29 20:00:45 [INFO]: Epoch 558 - training loss (MAE): 0.0256
# 2025-07-29 20:00:46 [INFO]: Epoch 559 - training loss (MAE): 0.0264
# 2025-07-29 20:00:47 [INFO]: Epoch 560 - training loss (MAE): 0.0260
# 2025-07-29 20:00:48 [INFO]: Epoch 561 - training loss (MAE): 0.0259
# 2025-07-29 20:00:49 [INFO]: Epoch 562 - training loss (MAE): 0.0260
# 2025-07-29 20:00:50 [INFO]: Epoch 563 - training loss (MAE): 0.0258
# 2025-07-29 20:00:51 [INFO]: Epoch 564 - training loss (MAE): 0.0258
# 2025-07-29 20:00:52 [INFO]: Epoch 565 - training loss (MAE): 0.0262
# 2025-07-29 20:00:53 [INFO]: Epoch 566 - training loss (MAE): 0.0260
# 2025-07-29 20:00:54 [INFO]: Epoch 567 - training loss (MAE): 0.0264
# 2025-07-29 20:00:55 [INFO]: Epoch 568 - training loss (MAE): 0.0261
# 2025-07-29 20:00:56 [INFO]: Epoch 569 - training loss (MAE): 0.0262
# 2025-07-29 20:00:57 [INFO]: Epoch 570 - training loss (MAE): 0.0266
# 2025-07-29 20:00:58 [INFO]: Epoch 571 - training loss (MAE): 0.0269
# 2025-07-29 20:00:59 [INFO]: Epoch 572 - training loss (MAE): 0.0270
# 2025-07-29 20:01:00 [INFO]: Epoch 573 - training loss (MAE): 0.0262
# 2025-07-29 20:01:00 [INFO]: Epoch 574 - training loss (MAE): 0.0260
# 2025-07-29 20:01:01 [INFO]: Epoch 575 - training loss (MAE): 0.0262
# 2025-07-29 20:01:02 [INFO]: Epoch 576 - training loss (MAE): 0.0255
# 2025-07-29 20:01:03 [INFO]: Epoch 577 - training loss (MAE): 0.0264
# 2025-07-29 20:01:04 [INFO]: Epoch 578 - training loss (MAE): 0.0260
# 2025-07-29 20:01:05 [INFO]: Epoch 579 - training loss (MAE): 0.0256
# 2025-07-29 20:01:06 [INFO]: Epoch 580 - training loss (MAE): 0.0265
# 2025-07-29 20:01:07 [INFO]: Epoch 581 - training loss (MAE): 0.0259
# 2025-07-29 20:01:08 [INFO]: Epoch 582 - training loss (MAE): 0.0261
# 2025-07-29 20:01:09 [INFO]: Epoch 583 - training loss (MAE): 0.0257
# 2025-07-29 20:01:10 [INFO]: Epoch 584 - training loss (MAE): 0.0257
# 2025-07-29 20:01:11 [INFO]: Epoch 585 - training loss (MAE): 0.0272
# 2025-07-29 20:01:12 [INFO]: Epoch 586 - training loss (MAE): 0.0274
# 2025-07-29 20:01:13 [INFO]: Epoch 587 - training loss (MAE): 0.0263
# 2025-07-29 20:01:14 [INFO]: Epoch 588 - training loss (MAE): 0.0257
# 2025-07-29 20:01:15 [INFO]: Epoch 589 - training loss (MAE): 0.0256
# 2025-07-29 20:01:16 [INFO]: Epoch 590 - training loss (MAE): 0.0255
# 2025-07-29 20:01:17 [INFO]: Epoch 591 - training loss (MAE): 0.0258
# 2025-07-29 20:01:18 [INFO]: Epoch 592 - training loss (MAE): 0.0258
# 2025-07-29 20:01:19 [INFO]: Epoch 593 - training loss (MAE): 0.0258
# 2025-07-29 20:01:20 [INFO]: Epoch 594 - training loss (MAE): 0.0259
# 2025-07-29 20:01:21 [INFO]: Epoch 595 - training loss (MAE): 0.0258
# 2025-07-29 20:01:22 [INFO]: Epoch 596 - training loss (MAE): 0.0258
# 2025-07-29 20:01:23 [INFO]: Epoch 597 - training loss (MAE): 0.0259
# 2025-07-29 20:01:24 [INFO]: Epoch 598 - training loss (MAE): 0.0257
# 2025-07-29 20:01:25 [INFO]: Epoch 599 - training loss (MAE): 0.0261
# 2025-07-29 20:01:26 [INFO]: Epoch 600 - training loss (MAE): 0.0255
# 2025-07-29 20:01:27 [INFO]: Epoch 601 - training loss (MAE): 0.0259
# 2025-07-29 20:01:28 [INFO]: Epoch 602 - training loss (MAE): 0.0253
# 2025-07-29 20:01:29 [INFO]: Epoch 603 - training loss (MAE): 0.0258
# 2025-07-29 20:01:30 [INFO]: Epoch 604 - training loss (MAE): 0.0272
# 2025-07-29 20:01:31 [INFO]: Epoch 605 - training loss (MAE): 0.0276
# 2025-07-29 20:01:32 [INFO]: Epoch 606 - training loss (MAE): 0.0272
# 2025-07-29 20:01:33 [INFO]: Epoch 607 - training loss (MAE): 0.0258
# 2025-07-29 20:01:34 [INFO]: Epoch 608 - training loss (MAE): 0.0257
# 2025-07-29 20:01:35 [INFO]: Epoch 609 - training loss (MAE): 0.0254
# 2025-07-29 20:01:35 [INFO]: Epoch 610 - training loss (MAE): 0.0254
# 2025-07-29 20:01:36 [INFO]: Epoch 611 - training loss (MAE): 0.0257
# 2025-07-29 20:01:37 [INFO]: Epoch 612 - training loss (MAE): 0.0258
# 2025-07-29 20:01:38 [INFO]: Epoch 613 - training loss (MAE): 0.0256
# 2025-07-29 20:01:39 [INFO]: Epoch 614 - training loss (MAE): 0.0251
# 2025-07-29 20:01:40 [INFO]: Epoch 615 - training loss (MAE): 0.0254
# 2025-07-29 20:01:41 [INFO]: Epoch 616 - training loss (MAE): 0.0252
# 2025-07-29 20:01:42 [INFO]: Epoch 617 - training loss (MAE): 0.0250
# 2025-07-29 20:01:43 [INFO]: Epoch 618 - training loss (MAE): 0.0249
# 2025-07-29 20:01:44 [INFO]: Epoch 619 - training loss (MAE): 0.0250
# 2025-07-29 20:01:45 [INFO]: Epoch 620 - training loss (MAE): 0.0250
# 2025-07-29 20:01:46 [INFO]: Epoch 621 - training loss (MAE): 0.0247
# 2025-07-29 20:01:47 [INFO]: Epoch 622 - training loss (MAE): 0.0252
# 2025-07-29 20:01:48 [INFO]: Epoch 623 - training loss (MAE): 0.0250
# 2025-07-29 20:01:49 [INFO]: Epoch 624 - training loss (MAE): 0.0259
# 2025-07-29 20:01:50 [INFO]: Epoch 625 - training loss (MAE): 0.0251
# 2025-07-29 20:01:51 [INFO]: Epoch 626 - training loss (MAE): 0.0247
# 2025-07-29 20:01:52 [INFO]: Epoch 627 - training loss (MAE): 0.0249
# 2025-07-29 20:01:53 [INFO]: Epoch 628 - training loss (MAE): 0.0254
# 2025-07-29 20:01:54 [INFO]: Epoch 629 - training loss (MAE): 0.0261
# 2025-07-29 20:01:55 [INFO]: Epoch 630 - training loss (MAE): 0.0256
# 2025-07-29 20:01:56 [INFO]: Epoch 631 - training loss (MAE): 0.0251
# 2025-07-29 20:01:57 [INFO]: Epoch 632 - training loss (MAE): 0.0251
# 2025-07-29 20:01:58 [INFO]: Epoch 633 - training loss (MAE): 0.0253
# 2025-07-29 20:01:59 [INFO]: Epoch 634 - training loss (MAE): 0.0257
# 2025-07-29 20:02:00 [INFO]: Epoch 635 - training loss (MAE): 0.0259
# 2025-07-29 20:02:01 [INFO]: Epoch 636 - training loss (MAE): 0.0251
# 2025-07-29 20:02:02 [INFO]: Epoch 637 - training loss (MAE): 0.0252
# 2025-07-29 20:02:03 [INFO]: Epoch 638 - training loss (MAE): 0.0254
# 2025-07-29 20:02:04 [INFO]: Epoch 639 - training loss (MAE): 0.0260
# 2025-07-29 20:02:05 [INFO]: Epoch 640 - training loss (MAE): 0.0259
# 2025-07-29 20:02:06 [INFO]: Epoch 641 - training loss (MAE): 0.0258
# 2025-07-29 20:02:07 [INFO]: Epoch 642 - training loss (MAE): 0.0249
# 2025-07-29 20:02:07 [INFO]: Epoch 643 - training loss (MAE): 0.0251
# 2025-07-29 20:02:08 [INFO]: Epoch 644 - training loss (MAE): 0.0251
# 2025-07-29 20:02:09 [INFO]: Epoch 645 - training loss (MAE): 0.0259
# 2025-07-29 20:02:10 [INFO]: Epoch 646 - training loss (MAE): 0.0256
# 2025-07-29 20:02:11 [INFO]: Epoch 647 - training loss (MAE): 0.0248
# 2025-07-29 20:02:12 [INFO]: Epoch 648 - training loss (MAE): 0.0250
# 2025-07-29 20:02:13 [INFO]: Epoch 649 - training loss (MAE): 0.0250
# 2025-07-29 20:02:14 [INFO]: Epoch 650 - training loss (MAE): 0.0254
# 2025-07-29 20:02:15 [INFO]: Epoch 651 - training loss (MAE): 0.0257
# 2025-07-29 20:02:16 [INFO]: Epoch 652 - training loss (MAE): 0.0249
# 2025-07-29 20:02:17 [INFO]: Epoch 653 - training loss (MAE): 0.0247
# 2025-07-29 20:02:18 [INFO]: Epoch 654 - training loss (MAE): 0.0246
# 2025-07-29 20:02:19 [INFO]: Epoch 655 - training loss (MAE): 0.0251
# 2025-07-29 20:02:20 [INFO]: Epoch 656 - training loss (MAE): 0.0245
# 2025-07-29 20:02:21 [INFO]: Epoch 657 - training loss (MAE): 0.0250
# 2025-07-29 20:02:22 [INFO]: Epoch 658 - training loss (MAE): 0.0250
# 2025-07-29 20:02:23 [INFO]: Epoch 659 - training loss (MAE): 0.0254
# 2025-07-29 20:02:24 [INFO]: Epoch 660 - training loss (MAE): 0.0261
# 2025-07-29 20:02:25 [INFO]: Epoch 661 - training loss (MAE): 0.0264
# 2025-07-29 20:02:26 [INFO]: Epoch 662 - training loss (MAE): 0.0263
# 2025-07-29 20:02:27 [INFO]: Epoch 663 - training loss (MAE): 0.0250
# 2025-07-29 20:02:28 [INFO]: Epoch 664 - training loss (MAE): 0.0243
# 2025-07-29 20:02:29 [INFO]: Epoch 665 - training loss (MAE): 0.0243
# 2025-07-29 20:02:30 [INFO]: Epoch 666 - training loss (MAE): 0.0243
# 2025-07-29 20:02:31 [INFO]: Epoch 667 - training loss (MAE): 0.0253
# 2025-07-29 20:02:32 [INFO]: Epoch 668 - training loss (MAE): 0.0252
# 2025-07-29 20:02:33 [INFO]: Epoch 669 - training loss (MAE): 0.0250
# 2025-07-29 20:02:34 [INFO]: Epoch 670 - training loss (MAE): 0.0245
# 2025-07-29 20:02:35 [INFO]: Epoch 671 - training loss (MAE): 0.0248
# 2025-07-29 20:02:36 [INFO]: Epoch 672 - training loss (MAE): 0.0245
# 2025-07-29 20:02:37 [INFO]: Epoch 673 - training loss (MAE): 0.0243
# 2025-07-29 20:02:38 [INFO]: Epoch 674 - training loss (MAE): 0.0246
# 2025-07-29 20:02:39 [INFO]: Epoch 675 - training loss (MAE): 0.0246
# 2025-07-29 20:02:40 [INFO]: Epoch 676 - training loss (MAE): 0.0254
# 2025-07-29 20:02:41 [INFO]: Epoch 677 - training loss (MAE): 0.0248
# 2025-07-29 20:02:42 [INFO]: Epoch 678 - training loss (MAE): 0.0247
# 2025-07-29 20:02:43 [INFO]: Epoch 679 - training loss (MAE): 0.0250
# 2025-07-29 20:02:44 [INFO]: Epoch 680 - training loss (MAE): 0.0244
# 2025-07-29 20:02:45 [INFO]: Epoch 681 - training loss (MAE): 0.0241
# 2025-07-29 20:02:46 [INFO]: Epoch 682 - training loss (MAE): 0.0242
# 2025-07-29 20:02:47 [INFO]: Epoch 683 - training loss (MAE): 0.0241
# 2025-07-29 20:02:48 [INFO]: Epoch 684 - training loss (MAE): 0.0242
# 2025-07-29 20:02:49 [INFO]: Epoch 685 - training loss (MAE): 0.0244
# 2025-07-29 20:02:50 [INFO]: Epoch 686 - training loss (MAE): 0.0248
# 2025-07-29 20:02:51 [INFO]: Epoch 687 - training loss (MAE): 0.0248
# 2025-07-29 20:02:52 [INFO]: Epoch 688 - training loss (MAE): 0.0246
# 2025-07-29 20:02:53 [INFO]: Epoch 689 - training loss (MAE): 0.0249
# 2025-07-29 20:02:53 [INFO]: Epoch 690 - training loss (MAE): 0.0247
# 2025-07-29 20:02:54 [INFO]: Epoch 691 - training loss (MAE): 0.0242
# 2025-07-29 20:02:55 [INFO]: Epoch 692 - training loss (MAE): 0.0244
# 2025-07-29 20:02:56 [INFO]: Epoch 693 - training loss (MAE): 0.0240
# 2025-07-29 20:02:57 [INFO]: Epoch 694 - training loss (MAE): 0.0247
# 2025-07-29 20:02:58 [INFO]: Epoch 695 - training loss (MAE): 0.0244
# 2025-07-29 20:02:59 [INFO]: Epoch 696 - training loss (MAE): 0.0244
# 2025-07-29 20:03:00 [INFO]: Epoch 697 - training loss (MAE): 0.0241
# 2025-07-29 20:03:01 [INFO]: Epoch 698 - training loss (MAE): 0.0241
# 2025-07-29 20:03:02 [INFO]: Epoch 699 - training loss (MAE): 0.0238
# 2025-07-29 20:03:03 [INFO]: Epoch 700 - training loss (MAE): 0.0243
# 2025-07-29 20:03:04 [INFO]: Epoch 701 - training loss (MAE): 0.0242
# 2025-07-29 20:03:05 [INFO]: Epoch 702 - training loss (MAE): 0.0251
# 2025-07-29 20:03:06 [INFO]: Epoch 703 - training loss (MAE): 0.0261
# 2025-07-29 20:03:07 [INFO]: Epoch 704 - training loss (MAE): 0.0248
# 2025-07-29 20:03:08 [INFO]: Epoch 705 - training loss (MAE): 0.0241
# 2025-07-29 20:03:09 [INFO]: Epoch 706 - training loss (MAE): 0.0241
# 2025-07-29 20:03:10 [INFO]: Epoch 707 - training loss (MAE): 0.0239
# 2025-07-29 20:03:11 [INFO]: Epoch 708 - training loss (MAE): 0.0235
# 2025-07-29 20:03:12 [INFO]: Epoch 709 - training loss (MAE): 0.0239
# 2025-07-29 20:03:13 [INFO]: Epoch 710 - training loss (MAE): 0.0243
# 2025-07-29 20:03:14 [INFO]: Epoch 711 - training loss (MAE): 0.0239
# 2025-07-29 20:03:15 [INFO]: Epoch 712 - training loss (MAE): 0.0241
# 2025-07-29 20:03:16 [INFO]: Epoch 713 - training loss (MAE): 0.0247
# 2025-07-29 20:03:17 [INFO]: Epoch 714 - training loss (MAE): 0.0250
# 2025-07-29 20:03:18 [INFO]: Epoch 715 - training loss (MAE): 0.0261
# 2025-07-29 20:03:19 [INFO]: Epoch 716 - training loss (MAE): 0.0255
# 2025-07-29 20:03:20 [INFO]: Epoch 717 - training loss (MAE): 0.0243
# 2025-07-29 20:03:21 [INFO]: Epoch 718 - training loss (MAE): 0.0240
# 2025-07-29 20:03:22 [INFO]: Epoch 719 - training loss (MAE): 0.0244
# 2025-07-29 20:03:23 [INFO]: Epoch 720 - training loss (MAE): 0.0252
# 2025-07-29 20:03:24 [INFO]: Epoch 721 - training loss (MAE): 0.0249
# 2025-07-29 20:03:25 [INFO]: Epoch 722 - training loss (MAE): 0.0246
# 2025-07-29 20:03:26 [INFO]: Epoch 723 - training loss (MAE): 0.0245
# 2025-07-29 20:03:27 [INFO]: Epoch 724 - training loss (MAE): 0.0239
# 2025-07-29 20:03:28 [INFO]: Epoch 725 - training loss (MAE): 0.0240
# 2025-07-29 20:03:29 [INFO]: Epoch 726 - training loss (MAE): 0.0237
# 2025-07-29 20:03:30 [INFO]: Epoch 727 - training loss (MAE): 0.0243
# 2025-07-29 20:03:31 [INFO]: Epoch 728 - training loss (MAE): 0.0244
# 2025-07-29 20:03:32 [INFO]: Epoch 729 - training loss (MAE): 0.0246
# 2025-07-29 20:03:32 [INFO]: Epoch 730 - training loss (MAE): 0.0245
# 2025-07-29 20:03:33 [INFO]: Epoch 731 - training loss (MAE): 0.0241
# 2025-07-29 20:03:34 [INFO]: Epoch 732 - training loss (MAE): 0.0248
# 2025-07-29 20:03:35 [INFO]: Epoch 733 - training loss (MAE): 0.0243
# 2025-07-29 20:03:36 [INFO]: Epoch 734 - training loss (MAE): 0.0241
# 2025-07-29 20:03:37 [INFO]: Epoch 735 - training loss (MAE): 0.0240
# 2025-07-29 20:03:38 [INFO]: Epoch 736 - training loss (MAE): 0.0238
# 2025-07-29 20:03:39 [INFO]: Epoch 737 - training loss (MAE): 0.0242
# 2025-07-29 20:03:40 [INFO]: Epoch 738 - training loss (MAE): 0.0240
# 2025-07-29 20:03:41 [INFO]: Epoch 739 - training loss (MAE): 0.0236
# 2025-07-29 20:03:42 [INFO]: Epoch 740 - training loss (MAE): 0.0239
# 2025-07-29 20:03:43 [INFO]: Epoch 741 - training loss (MAE): 0.0242
# 2025-07-29 20:03:44 [INFO]: Epoch 742 - training loss (MAE): 0.0243
# 2025-07-29 20:03:45 [INFO]: Epoch 743 - training loss (MAE): 0.0261
# 2025-07-29 20:03:46 [INFO]: Epoch 744 - training loss (MAE): 0.0250
# 2025-07-29 20:03:47 [INFO]: Epoch 745 - training loss (MAE): 0.0246
# 2025-07-29 20:03:48 [INFO]: Epoch 746 - training loss (MAE): 0.0248
# 2025-07-29 20:03:49 [INFO]: Epoch 747 - training loss (MAE): 0.0246
# 2025-07-29 20:03:50 [INFO]: Epoch 748 - training loss (MAE): 0.0249
# 2025-07-29 20:03:51 [INFO]: Epoch 749 - training loss (MAE): 0.0242
# 2025-07-29 20:03:52 [INFO]: Epoch 750 - training loss (MAE): 0.0244
# 2025-07-29 20:03:53 [INFO]: Epoch 751 - training loss (MAE): 0.0251
# 2025-07-29 20:03:54 [INFO]: Epoch 752 - training loss (MAE): 0.0243
# 2025-07-29 20:03:55 [INFO]: Epoch 753 - training loss (MAE): 0.0236
# 2025-07-29 20:03:56 [INFO]: Epoch 754 - training loss (MAE): 0.0236
# 2025-07-29 20:03:57 [INFO]: Epoch 755 - training loss (MAE): 0.0236
# 2025-07-29 20:03:58 [INFO]: Epoch 756 - training loss (MAE): 0.0238
# 2025-07-29 20:03:59 [INFO]: Epoch 757 - training loss (MAE): 0.0243
# 2025-07-29 20:04:00 [INFO]: Epoch 758 - training loss (MAE): 0.0244
# 2025-07-29 20:04:01 [INFO]: Epoch 759 - training loss (MAE): 0.0237
# 2025-07-29 20:04:02 [INFO]: Epoch 760 - training loss (MAE): 0.0235
# 2025-07-29 20:04:03 [INFO]: Epoch 761 - training loss (MAE): 0.0235
# 2025-07-29 20:04:04 [INFO]: Epoch 762 - training loss (MAE): 0.0233
# 2025-07-29 20:04:05 [INFO]: Epoch 763 - training loss (MAE): 0.0236
# 2025-07-29 20:04:06 [INFO]: Epoch 764 - training loss (MAE): 0.0237
# 2025-07-29 20:04:07 [INFO]: Epoch 765 - training loss (MAE): 0.0236
# 2025-07-29 20:04:08 [INFO]: Epoch 766 - training loss (MAE): 0.0238
# 2025-07-29 20:04:08 [INFO]: Epoch 767 - training loss (MAE): 0.0240
# 2025-07-29 20:04:09 [INFO]: Epoch 768 - training loss (MAE): 0.0236
# 2025-07-29 20:04:10 [INFO]: Epoch 769 - training loss (MAE): 0.0238
# 2025-07-29 20:04:11 [INFO]: Epoch 770 - training loss (MAE): 0.0234
# 2025-07-29 20:04:12 [INFO]: Epoch 771 - training loss (MAE): 0.0236
# 2025-07-29 20:04:13 [INFO]: Epoch 772 - training loss (MAE): 0.0236
# 2025-07-29 20:04:14 [INFO]: Epoch 773 - training loss (MAE): 0.0234
# 2025-07-29 20:04:15 [INFO]: Epoch 774 - training loss (MAE): 0.0239
# 2025-07-29 20:04:16 [INFO]: Epoch 775 - training loss (MAE): 0.0243
# 2025-07-29 20:04:17 [INFO]: Epoch 776 - training loss (MAE): 0.0238
# 2025-07-29 20:04:18 [INFO]: Epoch 777 - training loss (MAE): 0.0233
# 2025-07-29 20:04:19 [INFO]: Epoch 778 - training loss (MAE): 0.0242
# 2025-07-29 20:04:20 [INFO]: Epoch 779 - training loss (MAE): 0.0245
# 2025-07-29 20:04:21 [INFO]: Epoch 780 - training loss (MAE): 0.0238
# 2025-07-29 20:04:22 [INFO]: Epoch 781 - training loss (MAE): 0.0234
# 2025-07-29 20:04:23 [INFO]: Epoch 782 - training loss (MAE): 0.0238
# 2025-07-29 20:04:24 [INFO]: Epoch 783 - training loss (MAE): 0.0237
# 2025-07-29 20:04:25 [INFO]: Epoch 784 - training loss (MAE): 0.0241
# 2025-07-29 20:04:26 [INFO]: Epoch 785 - training loss (MAE): 0.0237
# 2025-07-29 20:04:27 [INFO]: Epoch 786 - training loss (MAE): 0.0234
# 2025-07-29 20:04:28 [INFO]: Epoch 787 - training loss (MAE): 0.0233
# 2025-07-29 20:04:29 [INFO]: Epoch 788 - training loss (MAE): 0.0238
# 2025-07-29 20:04:30 [INFO]: Epoch 789 - training loss (MAE): 0.0241
# 2025-07-29 20:04:31 [INFO]: Epoch 790 - training loss (MAE): 0.0237
# 2025-07-29 20:04:32 [INFO]: Epoch 791 - training loss (MAE): 0.0235
# 2025-07-29 20:04:33 [INFO]: Epoch 792 - training loss (MAE): 0.0235
# 2025-07-29 20:04:34 [INFO]: Epoch 793 - training loss (MAE): 0.0238
# 2025-07-29 20:04:35 [INFO]: Epoch 794 - training loss (MAE): 0.0240
# 2025-07-29 20:04:36 [INFO]: Epoch 795 - training loss (MAE): 0.0237
# 2025-07-29 20:04:37 [INFO]: Epoch 796 - training loss (MAE): 0.0237
# 2025-07-29 20:04:38 [INFO]: Epoch 797 - training loss (MAE): 0.0241
# 2025-07-29 20:04:39 [INFO]: Epoch 798 - training loss (MAE): 0.0238
# 2025-07-29 20:04:40 [INFO]: Epoch 799 - training loss (MAE): 0.0238
# 2025-07-29 20:04:41 [INFO]: Epoch 800 - training loss (MAE): 0.0233
# 2025-07-29 20:04:41 [INFO]: Finished training. The best model is from epoch#800.

# %% [markdown]
# # RMSE of pre-imputation

# %%
if pre_imputation == 'Pyraformer':
    result_pre = pyraformer.predict(test_set)
    
elif pre_imputation == 'SAITS':
    result_pre = saits.predict(test_set)
    
elif pre_imputation == 'ImputeFormer':
    result_pre = imputeFormer.predict(test_set)
    
elif pre_imputation == 'Informer':
    result_pre = informer.predict(test_set)
    
elif pre_imputation == 'etsformer':
    result_pre = eTSformer.predict(test_set)
    
elif pre_imputation == 'csdi':
    result_pre = csdi.predict(test_set, n_sampling_times=2)  
    

if pre_imputation == 'csdi':
    result_pre = result_pre["imputation"]
    result_pre = result_pre.mean(axis=1)
else:   
    result_pre = result_pre["imputation"]

# %%
rmse = calc_rmse( result_pre, target.cpu().numpy(), 1-Mask_test.cpu().numpy())
mae = calc_mae( result_pre, target.cpu().numpy(), 1-Mask_test.cpu().numpy())  
print(np.around(rmse,5), np.around(mae,5) )
# Out:
# 0.06402 0.04131

# %% [markdown]
# # flow inversion
# # input pre-imputation result to get inverted code

# %%
# x_t = torch.tensor(result_pre).cuda()*(1- Mask_test) + target*Mask_test

'利用细化后的结果 再逆推 再优化'
'做个几次会进一步降低rmse 但是不会一直降低'
# x_t = refined_res*(1- Mask_test) + target*Mask_test
# Out:
# '做个几次会进一步降低rmse 但是不会一直降低'

# %%
n_steps =100  # 较小的值时需要一些优化次数 但不能太小 逆推要精确
eps = 1e-8
# eps = 0

d = torch.tensor(1 / n_steps).to(device)

padding_masks = torch.ones(b, c, dtype=bool, device=device)

# %% [markdown]
# # refine pre-imputation result guided by pre-trained flow prior
# # set inversion step K and refinement step N

# %%
loss_list = []
loss_missing_list = []

'有些情况下 增加逆推次数 比增加细化次数要有效'
'但是有些场景 逆推会时效果变差 rmse曲线变成对钩形状 就是rmse反而上升了 此时增加细化次数更有效'
'不过好像不管怎么调二者的次数 有些场景 特别是低rmse时 只要到了一定次数 都会出现rmse上升的情况'
'就是说到了一定的极限 rmse就会上升 主要就是要找到那个最优点'
'此时即使调整采样步 也是一样会出现负优化'
'总体来讲 还是逆推次数多一些 有利于快速到达最优点 优化次数少一些'
'如果只增加逆推次数 会很快到达最优点后开始负优化 所以需要加一些细化的次数 '
'可以理解为逆推是粗优化 要配合细化'
'要改善负优化可能需要调整逆推公式'

inversion_iter = 1
refine_iter = 2

pbar = tqdm( total= inversion_iter * refine_iter + inversion_iter )   # 总的优化次数 其实应该应该加上逆推的次数


'逆推阶段 注意t的顺序'
'一次逆推下有几次优化阶段'
'第一次逆推用预补全的数据 后面的逆推用细化后的数据'
for j in range(0, inversion_iter  ):
    
    if j==0:       # 第一次逆推用预补全的数据
        x_t = torch.tensor(result_pre).cuda()*(1- Mask_test) + target*Mask_test
    else:          # 后面的逆推用细化的数据
        x_t = refined_res*(1- Mask_test) + target*Mask_test
        
    t = torch.linspace( 1-eps, eps, n_steps+1 ).to(device)
#     t = torch.arange(1, 0.0, -d).to(device)
    
    for i in range(1, len(t)):
        t_batch = t[ i-1 ].unsqueeze(0).repeat((b,))
        d_batch = d.unsqueeze(0).repeat((b,))
        with torch.no_grad():
            v_pred = ema.ema_model.output(x_t, t_batch, d=d_batch, padding_masks=padding_masks) 
        x_t = x_t - (t[i-1] - t[i]) * v_pred
        
    inverted_code = Variable( x_t, requires_grad=True)
    optimizer = torch.optim.Adam(  [inverted_code], lr=0.001)  

    pbar.update(1)
    
    
    '得到逆推码后开始细化 注意t的顺序和逆推不一样'
    t = torch.linspace( eps, 1-eps , n_steps+1 ).to(device)
        
    for i in range(0, refine_iter):
        
        x_t = inverted_code

        for i in range(1, len(t)):
            t_batch = t[ i-1 ].unsqueeze(0).repeat((b,))
            d_batch = d.unsqueeze(0).repeat((b,))

            with torch.no_grad():
                v_pred = ema.ema_model.output(x_t, t_batch, d=d_batch, padding_masks=padding_masks) 

            x_t = x_t + (t[i] - t[i - 1]) * v_pred

        refined_res = x_t

        loss = F.mse_loss( x_t*Mask_test , target*Mask_test , reduction="none")
        loss = loss.sum()/Mask.sum()
        loss_list.append(loss.item() )


        loss_missing = F.mse_loss( x_t*(1-Mask_test), target*(1-Mask_test), reduction="none")
        loss_missing = loss_missing.sum()/(1-Mask_test).sum()
        loss_missing_list.append(loss_missing.item() )


        loss.float().backward() 
        optimizer.step()
        optimizer.zero_grad()

        pbar.update(1)

pbar.close()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:21<00:00,  7.27s/it]

# %%
rmse1 = list( map(lambda x: x ** (1/2), loss_list) )
rmse2 = list( map(lambda x: x ** (1/2), loss_missing_list) )
# print( loss_list[-5:]  )
# print( rmse1[-5:]  )
# print( loss_missing_list[-5:]  )
print( np.around( rmse2, 5 )  )

# plt.figure()
# plt.plot(loss_list)
# plt.plot(rmse1)

plt.figure()
# plt.plot(rmse1)
plt.plot(rmse2)
plt.title('evolution of refined RMSE')
# Out:
# [0.06579 0.0645 ]
# Text(0.5, 1.0, 'evolution of refined RMSE')

# %% [markdown]
# # refined pre-imputation  RMSE

# %%
rmse = calc_rmse( refined_res, target,1-Mask_test).cpu()
mae = calc_mae( refined_res, target, 1-Mask_test).cpu() 
print( 'RMSE', rmse )
print( 'MAE', mae )
# Out:
# RMSE tensor(0.0645, grad_fn=<ToCopyBackward0>)
# MAE tensor(0.0408, grad_fn=<ToCopyBackward0>)

# %% [markdown]
# # visualization

# %%
visualization(ori_data=target.detach().cpu().numpy(), generated_data=refined_res.detach().cpu().numpy(), analysis='pca', compare=train_data.shape[0])
